# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2
from keras.callbacks import ModelCheckpoint
import h5py

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['DG', 'AXP', 'MUR', 'CSX', 'COO']

# %%
SYM = 'QCOM'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                  open        low       high   mv close
# date
# 2010-01-04  46.790001  46.570000  47.310001  46.939999
# 2010-01-05  47.520000  47.500000  48.320000  48.070000
# 2010-01-06  48.259998  47.380001  48.430000  47.599998
# 2010-01-07  47.750000  47.549999  49.020000  48.980000
# 2010-01-08  49.110001  48.889999  49.799999  49.470001

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.298281  0.300060  0.296815  0.301773
# 2010-01-05  0.312875  0.318739  0.317306  0.324537
# 2010-01-06  0.327669  0.316329  0.319537  0.315068
# 2010-01-07  0.317473  0.319743  0.331507  0.342869
# 2010-01-08  0.344662  0.346656  0.347332  0.352740

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 7
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.2982807  0.30006028 0.29681478 0.30177277]
#  [0.31287484 0.31873873 0.31730574 0.32453669]
#  [0.32766889 0.31632863 0.31953743 0.31506848]
#  [0.317473   0.31974293 0.3315074  0.34286868]
#  [0.34466215 0.34665596 0.34733209 0.35273977]
#  [0.35405841 0.34163487 0.3451004  0.34911367]
#  [0.33966415 0.33018681 0.33536212 0.33299765]] 0.3372280889852556

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='auto')

model.fit(X_train, y_train, batch_size=64, epochs=30, validation_split=0.05, verbose=1, callbacks=[checkpoint])

model = build_model([n_features,prev_days])
model.load_weights("weights.best.hdf5")
model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])
# Out:
# Train on 1500 samples, validate on 79 samples
# Epoch 1/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.1110 - mean_squared_error: 0.1110 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.00174, saving model to weights.best.hdf5
# Epoch 2/30
# 1500/1500 [==============================] - 1s 356us/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00002: val_mean_squared_error improved from 0.00174 to 0.00143, saving model to weights.best.hdf5
# Epoch 3/30
# 1500/1500 [==============================] - 1s 396us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00003: val_mean_squared_error did not improve
# Epoch 4/30
# 1500/1500 [==============================] - 1s 364us/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00004: val_mean_squared_error improved from 0.00143 to 0.00137, saving model to weights.best.hdf5
# Epoch 5/30
# 1500/1500 [==============================] - 1s 404us/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 6/30
# 1500/1500 [==============================] - 1s 351us/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00006: val_mean_squared_error did not improve
# Epoch 7/30
# 1500/1500 [==============================] - 1s 383us/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00007: val_mean_squared_error did not improve
# Epoch 8/30
# 1500/1500 [==============================] - 1s 367us/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00008: val_mean_squared_error did not improve
# Epoch 9/30
# 1500/1500 [==============================] - 1s 385us/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 10/30
# 1500/1500 [==============================] - 1s 404us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 11/30
# 1500/1500 [==============================] - 1s 400us/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 12/30
# 1500/1500 [==============================] - 1s 398us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00012: val_mean_squared_error did not improve
# Epoch 13/30
# 1500/1500 [==============================] - 1s 368us/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 14/30
# 1500/1500 [==============================] - 1s 395us/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00014: val_mean_squared_error did not improve
# Epoch 15/30
# 1500/1500 [==============================] - 1s 365us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 16/30
# 1500/1500 [==============================] - 1s 380us/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00016: val_mean_squared_error did not improve
# Epoch 17/30
# 1500/1500 [==============================] - 1s 366us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 18/30
# 1500/1500 [==============================] - 1s 364us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00018: val_mean_squared_error did not improve
# Epoch 19/30
# 1500/1500 [==============================] - 1s 370us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00019: val_mean_squared_error did not improve
# Epoch 20/30
# 1500/1500 [==============================] - 1s 376us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00020: val_mean_squared_error did not improve
# Epoch 21/30
# 1500/1500 [==============================] - 1s 377us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 22/30
# 1500/1500 [==============================] - 1s 371us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00022: val_mean_squared_error did not improve
# Epoch 23/30
# 1500/1500 [==============================] - 1s 391us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 24/30
# 1500/1500 [==============================] - 1s 385us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 25/30
# 1500/1500 [==============================] - 1s 387us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 26/30
# 1500/1500 [==============================] - 1s 430us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00026: val_mean_squared_error did not improve
# Epoch 27/30
# 1500/1500 [==============================] - 1s 399us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 28/30
# 1500/1500 [==============================] - 1s 399us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00028: val_mean_squared_error did not improve
# Epoch 29/30
# 1500/1500 [==============================] - 1s 387us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 30/30
# 1500/1500 [==============================] - 1s 394us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00030: val_mean_squared_error did not improve

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00112 (RMSE: 0.03)
# (0.0011169802716800145, 0.03342125478913104)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell : " + str(newy_test[i]))
    print("Balance : " + str(balance))
    
print("Balance : " + str(balance))
plt2.figure(figsize=(18,8))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Sell [52.91]
# Balance: [100000.]
# Buy [51.110001]
# Sell [50.73]
# Balance: [92481.41259085]
# Buy [50.490002]
# Buy [51.130001]
# Buy [50.919998]
# Buy [51.200001]
# Buy [52.150002]
# Sell [51.509998]
# Balance: [56953.59416686]
# Sell [51.32]
# Balance: [67767.69415693]
# Sell [51.91]
# Balance: [75971.51231482]
# Sell [51.990002]
# Balance: [82133.85852611]
# Sell [52.790001]
# Balance: [86826.73576415]
# Sell [52.759998]
# Balance: [90344.39330825]
# Sell [54.52]
# Balance: [93070.64468107]
# Buy [54.18]
# Sell [55.59]
# Balance: [87720.52281883]
# Sell [55.98]
# Balance: [91232.39786135]
# Sell [55.740002]
# Balance: [93855.01203463]
# Sell [55.27]
# Balance: [95805.38717129]
# Sell [54.919998]
# Balance: [97258.90533581]
# Sell [54.790001]
# Balance: [98346.46357399]
# Sell [54.880001]
# Balance: [99163.47209895]
# Sell [54.939999]
# Balance: [99776.89839349]
# Buy [54.889999]
# Buy [54.84]
# Buy [54.939999]
# Buy [54.98]
# Buy [53.830002]
# Buy [52.830002]
# Buy [52.700001]
# Buy [53.279999]
# Buy [53.419998]
# Buy [53.549999]
# Sell [55.549999]
# Balance: [26166.78232644]
# Sell [52.119999]
# Balance: [44580.09501643]
# Sell [51.139999]
# Balance: [58130.41366503]
# Buy [52.509998]
# Buy [53.549999]
# Buy [53.57]
# Buy [53.]
# Buy [51.939999]
# Buy [52.369999]
# Sell [54.189999]
# Balance: [25675.31629422]
# Sell [54.119999]
# Balance: [44906.92892307]
# Sell [54.619999]
# Balance: [59463.89513657]
# Buy [54.830002]
# Sell [54.880001]
# Balance: [62935.87005395]
# Sell [54.75]
# Balance: [73015.91670054]
# Buy [55.349998]
# Buy [55.139999]
# Sell [55.82]
# Balance: [65775.75961001]
# Sell [59.93]
# Balance: [76050.26765683]
# Sell [61.150002]
# Balance: [83913.01821097]
# Buy [60.73]
# Sell [61.349998]
# Balance: [82354.89066868]
# Sell [62.509998]
# Balance: [88806.00861062]
# Sell [62.43]
# Balance: [93638.15513919]
# Sell [62.580002]
# Balance: [97270.972768]
# Sell [61.849998]
# Balance: [99963.80301603]
# Sell [60.599998]
# Balance: [101942.60875073]
# Sell [61.009998]
# Balance: [103436.75402178]
# Buy [60.98]
# Buy [62.]
# Buy [61.580002]
# Buy [61.990002]
# Buy [61.709999]
# Buy [61.740002]
# Sell [61.709999]
# Balance: [59581.2249566]
# Sell [62.43]
# Balance: [71830.8522876]
# Sell [62.07]
# Balance: [80965.09506072]
# Sell [62.279999]
# Balance: [87838.95478493]
# Sell [63.040001]
# Balance: [93057.26079223]
# Buy [62.759998]
# Sell [62.830002]
# Balance: [89460.74143243]
# Sell [63.09]
# Balance: [94283.22568434]
# Sell [62.610001]
# Balance: [97872.57118879]
# Sell [62.639999]
# Balance: [100565.87012528]
# Sell [62.970001]
# Balance: [102596.48601886]
# Sell [62.98]
# Balance: [104119.68977002]
# Sell [62.939999]
# Balance: [105261.36699978]
# Sell [63.07]
# Balance: [106119.39350152]
# Sell [63.470001]
# Balance: [106766.99469372]
# Buy [63.349998]
# Sell [63.09]
# Balance: [99739.52727074]
# Sell [62.43]
# Balance: [101945.60440796]
# Sell [62.689999]
# Balance: [103607.0529126]
# Sell [60.52]
# Balance: [104810.00631551]
# Buy [62.25]
# Buy [61.290001]
# Buy [61.59]
# Buy [62.540001]
# Buy [62.990002]
# Buy [62.860001]
# Sell [62.700001]
# Balance: [60853.88480824]
# Sell [63.57]
# Balance: [73053.75729049]
# Sell [63.52]
# Balance: [82196.46493646]
# Sell [62.75]
# Balance: [88970.37360441]
# Sell [62.310001]
# Balance: [94015.18144355]
# Sell [63.310001]
# Balance: [97859.50961175]
# Buy [63.450001]
# Buy [67.449997]
# Sell [68.5]
# Balance: [86217.01056027]
# Sell [67.110001]
# Balance: [92357.94373924]
# Sell [66.68]
# Balance: [96934.13303597]
# Sell [66.839996]
# Balance: [100374.51029627]
# Sell [67.540001]
# Balance: [102981.81614801]
# Sell [68.190002]
# Balance: [104956.11495552]
# Sell [67.25]
# Balance: [106416.42721806]
# Sell [66.089996]
# Balance: [107492.76957781]
# Buy [66.059998]
# Buy [65.699997]
# Buy [65.699997]
# Buy [65.190002]
# Buy [66.099998]
# Buy [65.790001]
# Buy [67.339996]
# Buy [67.93]
# Sell [68.059998]
# Balance: [48881.34847338]
# Sell [67.709999]
# Balance: [64840.28946135]
# Sell [68.199997]
# Balance: [76896.11293916]
# Sell [70.089996]
# Balance: [86188.5541764]
# Sell [68.400002]
# Balance: [92989.8421863]
# Sell [68.720001]
# Balance: [98114.67228691]
# Sell [68.339996]
# Balance: [101937.0405583]
# Sell [67.089996]
# Balance: [104751.38084636]
# Sell [66.949997]
# Balance: [106857.73147697]
# Sell [66.730003]
# Balance: [108432.30343586]
# Buy [68.459999]
# Buy [68.269997]
# Buy [67.879997]
# Buy [66.309998]
# Buy [66.879997]
# Buy [65.93]
# Buy [66.769997]
# Sell [66.300003]
# Balance: [56870.78950695]
# Buy [66.669998]
# Buy [67.309998]
# Buy [67.099998]
# Sell [68.309998]
# Balance: [48762.61959871]
# Sell [68.129997]
# Balance: [65138.22743955]
# Sell [68.290001]
# Balance: [77448.77703301]
# Sell [67.099998]
# Balance: [86520.79900918]
# Sell [66.769997]
# Balance: [93291.35301276]
# Sell [68.129997]
# Balance: [98472.69768116]
# Sell [64.160004]
# Balance: [102132.2651546]
# Buy [65.839996]
# Buy [66.360001]
# Buy [67.449997]
# Buy [68.339996]
# Buy [68.550003]
# Sell [68.519997]
# Balance: [67791.74070654]
# Sell [68.470001]
# Balance: [79527.77785239]
# Buy [69.339996]
# Sell [67.559998]
# Balance: [80648.64559226]
# Sell [68.029999]
# Balance: [89047.32058803]
# Sell [66.459999]
# Balance: [95200.95802767]
# Sell [67.019997]
# Balance: [99855.07443922]
# Buy [66.910004]
# Buy [67.160004]
# Buy [66.760002]
# Buy [66.860001]
# Buy [67.25]
# Buy [65.75]
# Sell : [65.75]
# Balance : [112629.17352174]
# Balance : [112629.17352174]

# %%
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
