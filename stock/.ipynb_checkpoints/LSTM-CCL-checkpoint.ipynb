# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2
from keras.callbacks import ModelCheckpoint
import h5py

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['ILMN', 'MDT', 'BIIB', 'TGNA', 'FIS']

# %%
SYM = 'NFLX'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  7.931428  7.565714  7.961429  7.640000
# 2010-01-05  7.652857  7.258572  7.657143  7.358572
# 2010-01-06  7.361429  7.197143  7.672857  7.617143
# 2010-01-07  7.731429  7.462857  7.757143  7.485714
# 2010-01-08  7.498571  7.465714  7.742857  7.614286

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.007820  0.005310  0.006209  0.005015
# 2010-01-05  0.005577  0.002739  0.003795  0.002744
# 2010-01-06  0.003231  0.002224  0.003920  0.004831
# 2010-01-07  0.006210  0.004449  0.004589  0.003770
# 2010-01-08  0.004335  0.004473  0.004475  0.004808

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 7
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.0078196  0.00530967 0.00620865 0.0050151 ]
#  [0.00557721 0.00273855 0.00379543 0.0027439 ]
#  [0.00323133 0.00222433 0.00392006 0.00483064]
#  [0.00620968 0.00444865 0.00458851 0.00376998]
#  [0.00433528 0.00447256 0.00447521 0.00480758]
#  [0.00563471 0.00499875 0.00416931 0.00472688]
#  [0.00457677 0.00435297 0.00320629 0.00373539]] 0.005568493939052961

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='auto')

model.fit(X_train, y_train, batch_size = 64, epochs = 100, validation_split = 0.05, verbose=1, callbacks=[checkpoint])

model.load_weights("weights.best.hdf5")
model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])
# Out:
# Train on 1500 samples, validate on 79 samples
# Epoch 1/100
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0198 - mean_squared_error: 0.0198 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.00159, saving model to weights.best.hdf5
# Epoch 2/100
# 1500/1500 [==============================] - 1s 384us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
#
# Epoch 00002: val_mean_squared_error did not improve
# Epoch 3/100
# 1500/1500 [==============================] - 1s 390us/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
#
# Epoch 00003: val_mean_squared_error did not improve
# Epoch 4/100
# 1500/1500 [==============================] - 1s 430us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0475 - val_mean_squared_error: 0.0475
#
# Epoch 00004: val_mean_squared_error did not improve
# Epoch 5/100
# 1500/1500 [==============================] - 1s 410us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
#
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 6/100
# 1500/1500 [==============================] - 1s 508us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00006: val_mean_squared_error did not improve
# Epoch 7/100
# 1500/1500 [==============================] - 1s 547us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
#
# Epoch 00007: val_mean_squared_error did not improve
# Epoch 8/100
# 1500/1500 [==============================] - 1s 513us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
#
# Epoch 00008: val_mean_squared_error did not improve
# Epoch 9/100
# 1500/1500 [==============================] - 1s 584us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
#
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 10/100
# 1500/1500 [==============================] - 1s 558us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
#
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 11/100
# 1500/1500 [==============================] - 1s 481us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 12/100
# 1500/1500 [==============================] - 1s 469us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
#
# Epoch 00012: val_mean_squared_error did not improve
# Epoch 13/100
# 1500/1500 [==============================] - 1s 472us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 14/100
# 1500/1500 [==============================] - 1s 441us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00014: val_mean_squared_error did not improve
# Epoch 15/100
# 1500/1500 [==============================] - ETA: 0s - loss: 0.0012 - mean_squared_error: 0.00 - 1s 449us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 16/100
# 1500/1500 [==============================] - 1s 454us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00016: val_mean_squared_error did not improve
# Epoch 17/100
# 1500/1500 [==============================] - 1s 457us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 18/100
# 1500/1500 [==============================] - 1s 448us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00018: val_mean_squared_error improved from 0.00159 to 0.00151, saving model to weights.best.hdf5
# Epoch 19/100
# 1500/1500 [==============================] - 1s 477us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
#
# Epoch 00019: val_mean_squared_error did not improve
# Epoch 20/100
# 1500/1500 [==============================] - 1s 472us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
#
# Epoch 00020: val_mean_squared_error did not improve
# Epoch 21/100
# 1500/1500 [==============================] - 1s 505us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
#
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 22/100
# 1500/1500 [==============================] - 1s 496us/step - loss: 9.9294e-04 - mean_squared_error: 9.9294e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00022: val_mean_squared_error did not improve
# Epoch 23/100
# 1500/1500 [==============================] - 1s 536us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0039 - val_mean_squared_error: 0.0039
#
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 24/100
# 1500/1500 [==============================] - 1s 495us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 25/100
# 1500/1500 [==============================] - 1s 480us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
#
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 26/100
# 1500/1500 [==============================] - 1s 496us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
#
# Epoch 00026: val_mean_squared_error did not improve
# Epoch 27/100
# 1500/1500 [==============================] - 1s 529us/step - loss: 9.4808e-04 - mean_squared_error: 9.4808e-04 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
#
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 28/100
# 1500/1500 [==============================] - 1s 607us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0076 - val_mean_squared_error: 0.0076
#
# Epoch 00028: val_mean_squared_error did not improve
# Epoch 29/100
# 1500/1500 [==============================] - 1s 599us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0068 - val_mean_squared_error: 0.0068
#
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 30/100
# 1500/1500 [==============================] - 1s 540us/step - loss: 9.5575e-04 - mean_squared_error: 9.5575e-04 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
#
# Epoch 00030: val_mean_squared_error did not improve
# Epoch 31/100
# 1500/1500 [==============================] - 1s 591us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0113 - val_mean_squared_error: 0.0113
#
# Epoch 00031: val_mean_squared_error did not improve
# Epoch 32/100
# 1500/1500 [==============================] - 1s 542us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
#
# Epoch 00032: val_mean_squared_error did not improve
# Epoch 33/100
# 1500/1500 [==============================] - 1s 514us/step - loss: 8.9389e-04 - mean_squared_error: 8.9389e-04 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
#
# Epoch 00033: val_mean_squared_error did not improve
# Epoch 34/100
# 1500/1500 [==============================] - 1s 544us/step - loss: 9.4678e-04 - mean_squared_error: 9.4678e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
#
# Epoch 00034: val_mean_squared_error did not improve
# Epoch 35/100
# 1500/1500 [==============================] - 1s 506us/step - loss: 8.9790e-04 - mean_squared_error: 8.9790e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
#
# Epoch 00035: val_mean_squared_error did not improve
# Epoch 36/100
# 1500/1500 [==============================] - 1s 519us/step - loss: 9.3537e-04 - mean_squared_error: 9.3537e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
#
# Epoch 00036: val_mean_squared_error did not improve
# Epoch 37/100
# 1500/1500 [==============================] - 1s 485us/step - loss: 8.7800e-04 - mean_squared_error: 8.7800e-04 - val_loss: 0.0045 - val_mean_squared_error: 0.0045
#
# Epoch 00037: val_mean_squared_error did not improve
# Epoch 38/100
# 1500/1500 [==============================] - 1s 511us/step - loss: 9.2654e-04 - mean_squared_error: 9.2654e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# Epoch 00038: val_mean_squared_error did not improve
# Epoch 39/100
# 1500/1500 [==============================] - 1s 359us/step - loss: 9.4895e-04 - mean_squared_error: 9.4895e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
#
# Epoch 00039: val_mean_squared_error did not improve
# Epoch 40/100
# 1500/1500 [==============================] - 1s 354us/step - loss: 9.4925e-04 - mean_squared_error: 9.4925e-04 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
#
# Epoch 00040: val_mean_squared_error did not improve
# Epoch 41/100
# 1500/1500 [==============================] - 1s 364us/step - loss: 8.9754e-04 - mean_squared_error: 8.9754e-04 - val_loss: 0.0028 - val_mean_squared_error: 0.0028
#
# Epoch 00041: val_mean_squared_error did not improve
# Epoch 42/100
# 1500/1500 [==============================] - 1s 349us/step - loss: 9.9494e-04 - mean_squared_error: 9.9494e-04 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
#
# Epoch 00042: val_mean_squared_error did not improve
# Epoch 43/100
# 1500/1500 [==============================] - 1s 356us/step - loss: 9.6270e-04 - mean_squared_error: 9.6270e-04 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
#
# Epoch 00043: val_mean_squared_error did not improve
# Epoch 44/100
# 1500/1500 [==============================] - 1s 344us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
#
# Epoch 00044: val_mean_squared_error did not improve
# Epoch 45/100
# 1500/1500 [==============================] - 1s 375us/step - loss: 9.1140e-04 - mean_squared_error: 9.1140e-04 - val_loss: 0.0044 - val_mean_squared_error: 0.0044
#
# Epoch 00045: val_mean_squared_error did not improve
# Epoch 46/100
# 1500/1500 [==============================] - 1s 387us/step - loss: 9.2541e-04 - mean_squared_error: 9.2541e-04 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
#
# Epoch 00046: val_mean_squared_error did not improve
# Epoch 47/100
# 1500/1500 [==============================] - 1s 502us/step - loss: 9.1420e-04 - mean_squared_error: 9.1420e-04 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
#
# Epoch 00047: val_mean_squared_error did not improve
# Epoch 48/100
# 1500/1500 [==============================] - 1s 475us/step - loss: 8.3564e-04 - mean_squared_error: 8.3564e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# Epoch 00048: val_mean_squared_error did not improve
# Epoch 49/100
# 1500/1500 [==============================] - 1s 490us/step - loss: 9.0906e-04 - mean_squared_error: 9.0906e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
#
# Epoch 00049: val_mean_squared_error did not improve
# Epoch 50/100
# 1500/1500 [==============================] - 1s 488us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00050: val_mean_squared_error did not improve
# Epoch 51/100
# 1500/1500 [==============================] - 1s 506us/step - loss: 9.1500e-04 - mean_squared_error: 9.1500e-04 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
#
# Epoch 00051: val_mean_squared_error did not improve
# Epoch 52/100
# 1500/1500 [==============================] - 1s 591us/step - loss: 8.2488e-04 - mean_squared_error: 8.2488e-04 - val_loss: 0.0082 - val_mean_squared_error: 0.0082
#
# Epoch 00052: val_mean_squared_error did not improve
# Epoch 53/100
# 1500/1500 [==============================] - 1s 592us/step - loss: 9.3651e-04 - mean_squared_error: 9.3651e-04 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
#
# Epoch 00053: val_mean_squared_error did not improve
# Epoch 54/100
# 1500/1500 [==============================] - 1s 578us/step - loss: 7.6605e-04 - mean_squared_error: 7.6605e-04 - val_loss: 0.0064 - val_mean_squared_error: 0.0064
#
# Epoch 00054: val_mean_squared_error did not improve
# Epoch 55/100
# 1500/1500 [==============================] - 1s 500us/step - loss: 8.6395e-04 - mean_squared_error: 8.6395e-04 - val_loss: 0.0062 - val_mean_squared_error: 0.0062
#
# Epoch 00055: val_mean_squared_error did not improve
# Epoch 56/100
# 1500/1500 [==============================] - 1s 456us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
#
# Epoch 00056: val_mean_squared_error did not improve
# Epoch 57/100
# 1500/1500 [==============================] - 1s 477us/step - loss: 9.4010e-04 - mean_squared_error: 9.4010e-04 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
#
# Epoch 00057: val_mean_squared_error did not improve
# Epoch 58/100
# 1500/1500 [==============================] - 1s 461us/step - loss: 8.5203e-04 - mean_squared_error: 8.5203e-04 - val_loss: 0.0097 - val_mean_squared_error: 0.0097
#
# Epoch 00058: val_mean_squared_error did not improve
# Epoch 59/100
# 1500/1500 [==============================] - 1s 363us/step - loss: 8.4051e-04 - mean_squared_error: 8.4051e-04 - val_loss: 0.0161 - val_mean_squared_error: 0.0161
#
# Epoch 00059: val_mean_squared_error did not improve
# Epoch 60/100
# 1500/1500 [==============================] - 1s 424us/step - loss: 9.7229e-04 - mean_squared_error: 9.7229e-04 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
#
# Epoch 00060: val_mean_squared_error did not improve
# Epoch 61/100
# 1500/1500 [==============================] - 1s 466us/step - loss: 8.0892e-04 - mean_squared_error: 8.0892e-04 - val_loss: 0.0134 - val_mean_squared_error: 0.0134
#
# Epoch 00061: val_mean_squared_error did not improve
# Epoch 62/100
# 1500/1500 [==============================] - 1s 566us/step - loss: 7.9708e-04 - mean_squared_error: 7.9708e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00062: val_mean_squared_error did not improve
# Epoch 63/100
# 1500/1500 [==============================] - 1s 367us/step - loss: 8.4307e-04 - mean_squared_error: 8.4307e-04 - val_loss: 0.0056 - val_mean_squared_error: 0.0056
#
# Epoch 00063: val_mean_squared_error did not improve
# Epoch 64/100
# 1500/1500 [==============================] - 1s 399us/step - loss: 7.5034e-04 - mean_squared_error: 7.5034e-04 - val_loss: 0.0055 - val_mean_squared_error: 0.0055
#
# Epoch 00064: val_mean_squared_error did not improve
# Epoch 65/100
# 1500/1500 [==============================] - 1s 377us/step - loss: 7.7365e-04 - mean_squared_error: 7.7365e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
#
# Epoch 00065: val_mean_squared_error did not improve
# Epoch 66/100
# 1500/1500 [==============================] - 1s 391us/step - loss: 8.0536e-04 - mean_squared_error: 8.0536e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# Epoch 00066: val_mean_squared_error did not improve
# Epoch 67/100
# 1500/1500 [==============================] - 1s 342us/step - loss: 8.7019e-04 - mean_squared_error: 8.7019e-04 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
#
# Epoch 00067: val_mean_squared_error did not improve
# Epoch 68/100
# 1500/1500 [==============================] - 1s 434us/step - loss: 7.7025e-04 - mean_squared_error: 7.7025e-04 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
#
# Epoch 00068: val_mean_squared_error did not improve
# Epoch 69/100
# 1500/1500 [==============================] - 1s 423us/step - loss: 8.1100e-04 - mean_squared_error: 8.1100e-04 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
#
# Epoch 00069: val_mean_squared_error did not improve
# Epoch 70/100
# 1500/1500 [==============================] - 1s 385us/step - loss: 7.3394e-04 - mean_squared_error: 7.3394e-04 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
#
# Epoch 00070: val_mean_squared_error did not improve
# Epoch 71/100
# 1500/1500 [==============================] - 0s 321us/step - loss: 8.8033e-04 - mean_squared_error: 8.8033e-04 - val_loss: 0.0128 - val_mean_squared_error: 0.0128
#
# Epoch 00071: val_mean_squared_error did not improve
# Epoch 72/100
# 1500/1500 [==============================] - 1s 364us/step - loss: 7.4665e-04 - mean_squared_error: 7.4665e-04 - val_loss: 0.0087 - val_mean_squared_error: 0.0087
#
# Epoch 00072: val_mean_squared_error did not improve
# Epoch 73/100
# 1500/1500 [==============================] - 1s 381us/step - loss: 7.9635e-04 - mean_squared_error: 7.9635e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
#
# Epoch 00073: val_mean_squared_error did not improve
# Epoch 74/100
# 1500/1500 [==============================] - 0s 327us/step - loss: 8.3630e-04 - mean_squared_error: 8.3630e-04 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
#
# Epoch 00074: val_mean_squared_error did not improve
# Epoch 75/100
# 1500/1500 [==============================] - 1s 353us/step - loss: 8.2265e-04 - mean_squared_error: 8.2265e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
#
# Epoch 00075: val_mean_squared_error did not improve
# Epoch 76/100
# 1500/1500 [==============================] - 1s 353us/step - loss: 7.7253e-04 - mean_squared_error: 7.7253e-04 - val_loss: 0.0063 - val_mean_squared_error: 0.0063
#
# Epoch 00076: val_mean_squared_error did not improve
# Epoch 77/100
# 1500/1500 [==============================] - 1s 344us/step - loss: 7.3569e-04 - mean_squared_error: 7.3569e-04 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
#
# Epoch 00077: val_mean_squared_error did not improve
# Epoch 78/100
# 1500/1500 [==============================] - 1s 340us/step - loss: 7.8973e-04 - mean_squared_error: 7.8973e-04 - val_loss: 0.0084 - val_mean_squared_error: 0.0084
#
# Epoch 00078: val_mean_squared_error did not improve
# Epoch 79/100
# 1500/1500 [==============================] - 1s 341us/step - loss: 8.1793e-04 - mean_squared_error: 8.1793e-04 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
#
# Epoch 00079: val_mean_squared_error did not improve
# Epoch 80/100
# 1500/1500 [==============================] - 1s 351us/step - loss: 6.9355e-04 - mean_squared_error: 6.9355e-04 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
#
# Epoch 00080: val_mean_squared_error did not improve
# Epoch 81/100
# 1500/1500 [==============================] - 1s 353us/step - loss: 7.6476e-04 - mean_squared_error: 7.6476e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# Epoch 00081: val_mean_squared_error did not improve
# Epoch 82/100
# 1500/1500 [==============================] - 1s 352us/step - loss: 7.8665e-04 - mean_squared_error: 7.8665e-04 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
#
# Epoch 00082: val_mean_squared_error did not improve
# Epoch 83/100
# 1500/1500 [==============================] - 1s 336us/step - loss: 7.6301e-04 - mean_squared_error: 7.6301e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00083: val_mean_squared_error did not improve
# Epoch 84/100
# 1500/1500 [==============================] - 1s 336us/step - loss: 6.6915e-04 - mean_squared_error: 6.6915e-04 - val_loss: 0.0077 - val_mean_squared_error: 0.0077
#
# Epoch 00084: val_mean_squared_error did not improve
# Epoch 85/100
# 1500/1500 [==============================] - 1s 346us/step - loss: 7.0387e-04 - mean_squared_error: 7.0387e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00085: val_mean_squared_error did not improve
# Epoch 86/100
# 1500/1500 [==============================] - 1s 340us/step - loss: 7.2844e-04 - mean_squared_error: 7.2844e-04 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
#
# Epoch 00086: val_mean_squared_error did not improve
# Epoch 87/100
# 1500/1500 [==============================] - 0s 323us/step - loss: 7.0681e-04 - mean_squared_error: 7.0681e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
#
# Epoch 00087: val_mean_squared_error did not improve
# Epoch 88/100
# 1500/1500 [==============================] - 1s 401us/step - loss: 7.2427e-04 - mean_squared_error: 7.2427e-04 - val_loss: 0.0095 - val_mean_squared_error: 0.0095
#
# Epoch 00088: val_mean_squared_error did not improve
# Epoch 89/100
# 1500/1500 [==============================] - 1s 421us/step - loss: 7.6472e-04 - mean_squared_error: 7.6472e-04 - val_loss: 0.0072 - val_mean_squared_error: 0.0072
#
# Epoch 00089: val_mean_squared_error did not improve
# Epoch 90/100
# 1500/1500 [==============================] - 1s 356us/step - loss: 7.6245e-04 - mean_squared_error: 7.6245e-04 - val_loss: 0.0066 - val_mean_squared_error: 0.0066
#
# Epoch 00090: val_mean_squared_error did not improve
# Epoch 91/100
# 1500/1500 [==============================] - 0s 333us/step - loss: 7.9358e-04 - mean_squared_error: 7.9358e-04 - val_loss: 0.0079 - val_mean_squared_error: 0.0079
#
# Epoch 00091: val_mean_squared_error did not improve
# Epoch 92/100
# 1500/1500 [==============================] - 1s 338us/step - loss: 7.3392e-04 - mean_squared_error: 7.3392e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# Epoch 00092: val_mean_squared_error did not improve
# Epoch 93/100
# 1500/1500 [==============================] - 1s 348us/step - loss: 7.0303e-04 - mean_squared_error: 7.0303e-04 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
#
# Epoch 00093: val_mean_squared_error did not improve
# Epoch 94/100
# 1500/1500 [==============================] - 1s 341us/step - loss: 7.0530e-04 - mean_squared_error: 7.0530e-04 - val_loss: 0.0107 - val_mean_squared_error: 0.0107
#
# Epoch 00094: val_mean_squared_error did not improve
# Epoch 95/100
# 1500/1500 [==============================] - 1s 348us/step - loss: 8.0673e-04 - mean_squared_error: 8.0673e-04 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
#
# Epoch 00095: val_mean_squared_error did not improve
# Epoch 96/100
# 1500/1500 [==============================] - 0s 322us/step - loss: 7.7131e-04 - mean_squared_error: 7.7131e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
#
# Epoch 00096: val_mean_squared_error did not improve
# Epoch 97/100
# 1500/1500 [==============================] - 1s 402us/step - loss: 7.2471e-04 - mean_squared_error: 7.2471e-04 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
#
# Epoch 00097: val_mean_squared_error did not improve
# Epoch 98/100
# 1500/1500 [==============================] - 1s 357us/step - loss: 7.4262e-04 - mean_squared_error: 7.4262e-04 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
#
# Epoch 00098: val_mean_squared_error did not improve
# Epoch 99/100
# 1500/1500 [==============================] - 0s 309us/step - loss: 7.7733e-04 - mean_squared_error: 7.7733e-04 - val_loss: 0.0178 - val_mean_squared_error: 0.0178
#
# Epoch 00099: val_mean_squared_error did not improve
# Epoch 100/100
# 1500/1500 [==============================] - 1s 338us/step - loss: 6.6418e-04 - mean_squared_error: 6.6418e-04 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
#
# Epoch 00100: val_mean_squared_error did not improve

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00193 (RMSE: 0.04)
# (0.0019282022158482244, 0.043911299409698915)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell : " + str(newy_test[i]))
    print("Balance : " + str(balance))
    
print("Balance : " + str(balance))
plt2.figure(figsize=(18,8))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Buy [92.43]
# Buy [91.040001]
# Buy [90.279999]
# Buy [90.029999]
# Buy [93.110001]
# Buy [91.540001]
# Buy [90.790001]
# Buy [89.370003]
# Buy [90.839996]
# Buy [90.540001]
# Sell [90.019997]
# Balance: [24734.90380575]
# Buy [87.739998]
# Buy [87.879997]
# Buy [89.120003]
# Buy [94.889999]
# Sell [97.889999]
# Balance: [27047.19790725]
# Sell [100.199997]
# Balance: [47811.28905689]
# Sell [102.809998]
# Balance: [63790.00337935]
# Sell [103.300003]
# Balance: [75831.15649838]
# Sell [102.57]
# Balance: [84798.20180005]
# Sell [101.510002]
# Balance: [91453.9840939]
# Sell [101.25]
# Balance: [96433.03500495]
# Sell [99.589996]
# Balance: [100106.09915544]
# Sell [100.739998]
# Balance: [102892.70792667]
# Sell [99.889999]
# Balance: [104965.0303872]
# Buy [97.860001]
# Buy [97.089996]
# Buy [93.75]
# Buy [93.849998]
# Buy [94.120003]
# Buy [94.290001]
# Buy [95.440002]
# Buy [94.449997]
# Buy [93.800003]
# Buy [90.989998]
# Buy [90.010002]
# Sell [97.910004]
# Balance: [28767.71727424]
# Sell [94.599998]
# Balance: [49614.10083128]
# Sell [95.099998]
# Balance: [65331.52479926]
# Sell [97.059998]
# Balance: [77362.54349785]
# Sell [94.669998]
# Balance: [86163.61916961]
# Sell [95.970001]
# Balance: [92855.0678244]
# Buy [96.43]
# Sell [98.019997]
# Balance: [90522.0768717]
# Buy [98.389999]
# Buy [98.809998]
# Buy [85.839996]
# Buy [87.910004]
# Buy [85.989998]
# Buy [85.889999]
# Buy [87.660004]
# Buy [91.410004]
# Buy [92.040001]
# Buy [91.650002]
# Sell [91.25]
# Balance: [28248.38590802]
# Sell [94.370003]
# Balance: [50159.07300023]
# Sell [93.559998]
# Balance: [66451.03900128]
# Sell [93.099998]
# Balance: [78609.93731148]
# Buy [93.440002]
# Sell [97.029999]
# Balance: [80710.10672269]
# Sell [95.110001]
# Balance: [89605.65812428]
# Sell [93.989998]
# Balance: [96198.75703333]
# Sell [93.93]
# Balance: [101140.42471371]
# Sell [95.889999]
# Balance: [104924.01229699]
# Sell [96.589996]
# Balance: [107782.41812669]
# Sell [95.309998]
# Balance: [109897.81308367]
# Sell [95.120003]
# Balance: [111481.19661276]
# Sell [96.370003]
# Balance: [112684.34004187]
# Sell [96.160004]
# Balance: [113584.7312945]
# Buy [95.870003]
# Sell [95.260002]
# Balance: [106737.79739518]
# Sell [95.940002]
# Balance: [109119.47775672]
# Buy [95.18]
# Buy [97.32]
# Sell [97.580002]
# Balance: [96005.98994534]
# Sell [97.300003]
# Balance: [101156.05381252]
# Sell [97.449997]
# Balance: [105024.55607047]
# Sell [97.449997]
# Balance: [107925.93276394]
# Sell [97.379997]
# Balance: [110100.40220265]
# Sell [97.379997]
# Balance: [111731.25428169]
# Sell [100.089996]
# Balance: [112988.43221681]
# Sell [99.150002]
# Balance: [113922.46058949]
# Sell [99.660004]
# Balance: [114626.58516953]
# Sell [96.5]
# Balance: [115137.93389956]
# Sell [99.050003]
# Balance: [115531.57970196]
# Sell [96.089996]
# Balance: [115817.99128021]
# Buy [97.010002]
# Buy [97.339996]
# Buy [99.480003]
# Buy [98.059998]
# Buy [98.25]
# Sell [94.879997]
# Balance: [78129.59823509]
# Buy [95.830002]
# Buy [95.940002]
# Buy [94.559998]
# Buy [97.07]
# Buy [97.480003]
# Buy [96.669998]
# Buy [98.550003]
# Sell [102.629997]
# Balance: [36715.52059632]
# Sell [102.339996]
# Balance: [58094.38105832]
# Sell [106.279999]
# Balance: [74745.82739405]
# Sell [105.07]
# Balance: [87092.22946609]
# Sell [104.82]
# Balance: [96329.99856188]
# Sell [103.330002]
# Balance: [103159.84042752]
# Sell [100.589996]
# Balance: [108146.3914242]
# Sell [99.5]
# Balance: [111845.77886753]
# Sell [100.230003]
# Balance: [114640.67545956]
# Buy [101.470001]
# Buy [99.800003]
# Buy [118.790001]
# Sell [121.870003]
# Balance: [95809.70635516]
# Sell [123.349998]
# Balance: [104288.20745091]
# Sell [127.5]
# Balance: [110861.022047]
# Sell [127.330002]
# Balance: [115784.0602568]
# Sell [126.510002]
# Balance: [119452.56079075]
# Sell [126.970001]
# Balance: [122213.94037992]
# Sell [126.470001]
# Balance: [124276.81946546]
# Sell [126.57]
# Balance: [125825.20210832]
# Sell [124.870003]
# Balance: [126970.89152086]
# Sell [123.300003]
# Balance: [127819.35495048]
# Buy [122.339996]
# Buy [122.139999]
# Buy [122.029999]
# Buy [124.580002]
# Buy [124.339996]
# Buy [122.190002]
# Buy [115.419998]
# Buy [114.779999]
# Buy [113.379997]
# Buy [113.589996]
# Buy [115.190002]
# Buy [115.029999]
# Buy [115.209999]
# Sell [117.959999]
# Balance: [32449.418729]
# Buy [118.040001]
# Sell [117.690002]
# Balance: [49223.36528836]
# Sell [117.410004]
# Balance: [69256.05149286]
# Sell [116.93]
# Balance: [84219.14184774]
# Sell [117.510002]
# Balance: [95497.12511249]
# Sell [117.]
# Balance: [103918.9021071]
# Sell [117.220001]
# Balance: [110247.11177205]
# Sell [120.809998]
# Balance: [115138.62553107]
# Sell [119.160004]
# Balance: [118757.15550835]
# Sell [124.57]
# Balance: [121594.26693923]
# Buy [125.389999]
# Sell [123.239998]
# Balance: [116156.5159005]
# Sell [122.879997]
# Balance: [119568.20740349]
# Sell [122.830002]
# Balance: [122125.93496921]
# Buy [123.779999]
# Sell [123.440002]
# Balance: [116546.89034755]
# Sell [125.]
# Balance: [119904.50991985]
# Sell [124.220001]
# Balance: [122407.01095962]
# Sell [125.449997]
# Balance: [124302.47110334]
# Buy [125.120003]
# Sell [126.5]
# Balance: [118263.5382783]
# Buy [125.580002]
# Sell [125.589996]
# Balance: [113713.16654734]
# Sell [128.350006]
# Balance: [117890.20996226]
# Sell [125.889999]
# Balance: [120962.94837332]
# Sell : [125.889999]
# Balance : [130181.16360649]
# Balance : [130181.16360649]

# %%
plt2.figure(figsize=(18,8))
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
