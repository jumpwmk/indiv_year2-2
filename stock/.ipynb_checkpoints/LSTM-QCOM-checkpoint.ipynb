# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2
from keras.callbacks import ModelCheckpoint
import h5py

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['GPN', 'BDX', 'SYK', 'HBAN', 'CBS']

# %%
SYM = 'QCOM'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                  open        low       high   mv close
# date
# 2010-01-04  46.790001  46.570000  47.310001  46.939999
# 2010-01-05  47.520000  47.500000  48.320000  48.070000
# 2010-01-06  48.259998  47.380001  48.430000  47.599998
# 2010-01-07  47.750000  47.549999  49.020000  48.980000
# 2010-01-08  49.110001  48.889999  49.799999  49.470001

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.298281  0.300060  0.296815  0.301773
# 2010-01-05  0.312875  0.318739  0.317306  0.324537
# 2010-01-06  0.327669  0.316329  0.319537  0.315068
# 2010-01-07  0.317473  0.319743  0.331507  0.342869
# 2010-01-08  0.344662  0.346656  0.347332  0.352740

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 7
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.2982807  0.30006028 0.29681478 0.30177277]
#  [0.31287484 0.31873873 0.31730574 0.32453669]
#  [0.32766889 0.31632863 0.31953743 0.31506848]
#  [0.317473   0.31974293 0.3315074  0.34286868]
#  [0.34466215 0.34665596 0.34733209 0.35273977]
#  [0.35405841 0.34163487 0.3451004  0.34911367]
#  [0.33966415 0.33018681 0.33536212 0.33299765]] 0.3372280889852556

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='auto')

model.fit(X_train, y_train, batch_size=64, epochs=30, validation_split=0.05, verbose=1, callbacks=[checkpoint])

model = build_model([n_features,prev_days])
model.load_weights("weights.best.hdf5")
model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])
# Out:
# Train on 1500 samples, validate on 79 samples
# Epoch 1/30
# 1500/1500 [==============================] - 2s 1ms/step - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.00242, saving model to weights.best.hdf5
# Epoch 2/30
# 1500/1500 [==============================] - 1s 392us/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00002: val_mean_squared_error improved from 0.00242 to 0.00197, saving model to weights.best.hdf5
# Epoch 3/30
# 1500/1500 [==============================] - 1s 492us/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00003: val_mean_squared_error improved from 0.00197 to 0.00133, saving model to weights.best.hdf5
# Epoch 4/30
# 1500/1500 [==============================] - 1s 454us/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
#
# Epoch 00004: val_mean_squared_error did not improve
# Epoch 5/30
# 1500/1500 [==============================] - 1s 540us/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 6/30
# 1500/1500 [==============================] - 1s 620us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00006: val_mean_squared_error did not improve
# Epoch 7/30
# 1500/1500 [==============================] - 1s 586us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00007: val_mean_squared_error did not improve
# Epoch 8/30
# 1500/1500 [==============================] - 1s 550us/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00008: val_mean_squared_error did not improve
# Epoch 9/30
# 1500/1500 [==============================] - 1s 601us/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 10/30
# 1500/1500 [==============================] - 1s 566us/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 11/30
# 1500/1500 [==============================] - 1s 552us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 12/30
# 1500/1500 [==============================] - 1s 668us/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00012: val_mean_squared_error improved from 0.00133 to 0.00133, saving model to weights.best.hdf5
# Epoch 13/30
# 1500/1500 [==============================] - 1s 618us/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 14/30
# 1500/1500 [==============================] - 1s 553us/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00014: val_mean_squared_error did not improve
# Epoch 15/30
# 1500/1500 [==============================] - 1s 561us/step - loss: 0.0033 - mean_squared_error: 0.0033 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 16/30
# 1500/1500 [==============================] - 1s 612us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00016: val_mean_squared_error did not improve
# Epoch 17/30
# 1500/1500 [==============================] - 1s 658us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 18/30
# 1500/1500 [==============================] - 1s 592us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00018: val_mean_squared_error did not improve
# Epoch 19/30
# 1500/1500 [==============================] - 1s 568us/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00019: val_mean_squared_error improved from 0.00133 to 0.00131, saving model to weights.best.hdf5
# Epoch 20/30
# 1500/1500 [==============================] - 1s 559us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00020: val_mean_squared_error did not improve
# Epoch 21/30
# 1500/1500 [==============================] - 1s 536us/step - loss: 0.0031 - mean_squared_error: 0.0031 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 22/30
# 1500/1500 [==============================] - 1s 515us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00022: val_mean_squared_error did not improve
# Epoch 23/30
# 1500/1500 [==============================] - 1s 625us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 24/30
# 1500/1500 [==============================] - 1s 522us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 25/30
# 1500/1500 [==============================] - 1s 551us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 26/30
# 1500/1500 [==============================] - 1s 590us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00026: val_mean_squared_error did not improve
# Epoch 27/30
# 1500/1500 [==============================] - 1s 529us/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 28/30
# 1500/1500 [==============================] - 1s 512us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00028: val_mean_squared_error improved from 0.00131 to 0.00131, saving model to weights.best.hdf5
# Epoch 29/30
# 1500/1500 [==============================] - 1s 518us/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 30/30
# 1500/1500 [==============================] - 1s 483us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00030: val_mean_squared_error did not improve

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00102 (RMSE: 0.03)
# (0.0010154817160218954, 0.03186662385666068)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell : " + str(newy_test[i]))
    print("Balance : " + str(balance))
    
print("Balance : " + str(balance))
plt2.figure(figsize=(18,8))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Sell [52.91]
# Balance: [100000.]
# Buy [51.110001]
# Buy [50.73]
# Buy [50.490002]
# Buy [51.130001]
# Buy [50.919998]
# Buy [51.200001]
# Buy [52.150002]
# Sell [51.509998]
# Balance: [47640.51164495]
# Sell [51.32]
# Balance: [60822.09424207]
# Sell [51.91]
# Balance: [70821.93766495]
# Sell [51.990002]
# Balance: [78333.37880667]
# Sell [52.790001]
# Balance: [84053.64669658]
# Sell [52.759998]
# Balance: [88341.40929433]
# Sell [54.52]
# Balance: [91664.50670276]
# Buy [54.18]
# Sell [55.59]
# Balance: [86770.80456427]
# Sell [55.98]
# Balance: [90627.39596048]
# Sell [55.740002]
# Balance: [93507.43899556]
# Sell [55.27]
# Balance: [95649.25779046]
# Sell [54.919998]
# Balance: [97245.44944867]
# Sell [54.790001]
# Balance: [98439.75952334]
# Sell [54.880001]
# Balance: [99336.96344142]
# Sell [54.939999]
# Balance: [100010.6020365]
# Buy [54.889999]
# Buy [54.84]
# Buy [54.939999]
# Buy [54.98]
# Buy [53.830002]
# Buy [52.830002]
# Buy [52.700001]
# Buy [53.279999]
# Buy [53.419998]
# Buy [53.549999]
# Buy [53.889999]
# Sell [55.549999]
# Balance: [26273.03362633]
# Sell [52.119999]
# Balance: [44761.11433266]
# Sell [51.139999]
# Balance: [58366.45460953]
# Buy [52.509998]
# Buy [53.549999]
# Buy [53.57]
# Buy [53.]
# Buy [51.939999]
# Buy [52.369999]
# Sell [54.189999]
# Balance: [25780.10464374]
# Sell [54.119999]
# Balance: [45090.20701437]
# Sell [54.619999]
# Balance: [59706.58439328]
# Buy [54.830002]
# Sell [54.880001]
# Balance: [63223.3297914]
# Sell [54.75]
# Balance: [73336.87475854]
# Buy [55.349998]
# Buy [55.139999]
# Sell [55.82]
# Balance: [66122.33241121]
# Sell [59.93]
# Balance: [76417.46601643]
# Sell [61.150002]
# Balance: [84296.00064703]
# Buy [60.73]
# Sell [61.349998]
# Balance: [82749.74987942]
# Sell [62.509998]
# Balance: [89209.94382607]
# Sell [62.43]
# Balance: [94048.88864681]
# Sell [62.580002]
# Balance: [97686.81724557]
# Sell [61.849998]
# Balance: [100383.43600595]
# Sell [60.599998]
# Balance: [102365.02570001]
# Sell [61.009998]
# Balance: [103861.2730671]
# Buy [60.98]
# Buy [62.]
# Buy [61.580002]
# Buy [61.990002]
# Buy [61.709999]
# Sell [61.740002]
# Balance: [67515.18877487]
# Sell [61.709999]
# Balance: [77750.64914147]
# Sell [62.43]
# Balance: [85516.81104037]
# Sell [62.07]
# Balance: [91307.84502721]
# Sell [62.279999]
# Balance: [95665.8149512]
# Sell [63.040001]
# Balance: [98974.17758099]
# Buy [62.759998]
# Sell [62.830002]
# Balance: [93949.97249396]
# Sell [63.09]
# Balance: [97697.26150081]
# Sell [62.610001]
# Balance: [100486.34576693]
# Sell [62.639999]
# Balance: [102579.16120596]
# Sell [62.970001]
# Balance: [104157.041862]
# Sell [62.98]
# Balance: [105340.64026766]
# Sell [62.939999]
# Balance: [106227.77526053]
# Sell [63.07]
# Balance: [106894.50077161]
# Sell [63.470001]
# Balance: [107397.7162725]
# Buy [63.349998]
# Sell [63.09]
# Balance: [100262.6079193]
# Sell [62.43]
# Balance: [102388.79890254]
# Sell [62.689999]
# Balance: [103990.08326838]
# Buy [60.52]
# Buy [62.25]
# Buy [61.290001]
# Buy [61.59]
# Buy [62.540001]
# Buy [62.990002]
# Buy [62.860001]
# Sell [62.700001]
# Balance: [52890.45567109]
# Sell [63.57]
# Balance: [67262.42522226]
# Sell [63.52]
# Balance: [78032.92434791]
# Sell [62.75]
# Balance: [86012.87735642]
# Sell [62.310001]
# Balance: [91955.87592145]
# Sell [63.310001]
# Balance: [96484.65828852]
# Buy [63.450001]
# Buy [67.449997]
# Sell [68.5]
# Balance: [85397.58229677]
# Sell [67.110001]
# Balance: [91946.62980523]
# Sell [66.68]
# Balance: [96826.94363354]
# Sell [66.839996]
# Balance: [100495.96159353]
# Sell [67.540001]
# Balance: [103276.5438592]
# Sell [68.190002]
# Balance: [105382.05067868]
# Sell [67.25]
# Balance: [106939.4124193]
# Sell [66.089996]
# Balance: [108087.28637329]
# Buy [66.059998]
# Buy [65.699997]
# Buy [65.699997]
# Buy [65.190002]
# Buy [66.099998]
# Buy [65.790001]
# Buy [67.339996]
# Buy [67.93]
# Sell [68.059998]
# Balance: [49531.11311789]
# Sell [67.709999]
# Balance: [65531.27690829]
# Sell [68.199997]
# Balance: [77618.2412262]
# Sell [70.089996]
# Balance: [86934.68533867]
# Sell [68.400002]
# Balance: [93753.54144111]
# Sell [68.720001]
# Balance: [98891.60925335]
# Sell [68.339996]
# Balance: [102723.85090746]
# Sell [67.089996]
# Balance: [105545.46078776]
# Sell [66.949997]
# Balance: [107657.25223527]
# Buy [66.730003]
# Buy [68.459999]
# Buy [68.269997]
# Buy [67.879997]
# Buy [66.309998]
# Buy [66.879997]
# Buy [65.93]
# Buy [66.769997]
# Buy [66.300003]
# Buy [66.669998]
# Buy [67.309998]
# Sell [67.099998]
# Balance: [28529.37770095]
# Sell [68.309998]
# Balance: [50312.2591292]
# Sell [68.129997]
# Balance: [66606.37078718]
# Sell [68.290001]
# Balance: [78855.65469752]
# Sell [67.099998]
# Balance: [87882.52811071]
# Sell [66.769997]
# Balance: [94619.38722415]
# Sell [68.129997]
# Balance: [99774.94599094]
# Sell [64.160004]
# Balance: [103416.30096302]
# Buy [65.839996]
# Buy [66.360001]
# Buy [67.449997]
# Buy [68.339996]
# Buy [68.550003]
# Sell [68.519997]
# Balance: [69061.18891607]
# Sell [68.470001]
# Balance: [80786.29334569]
# Buy [69.339996]
# Sell [67.559998]
# Balance: [81899.07052462]
# Sell [68.029999]
# Balance: [90291.63538641]
# Sell [66.459999]
# Balance: [96440.79598307]
# Buy [67.019997]
# Buy [66.910004]
# Buy [67.160004]
# Buy [66.760002]
# Buy [66.860001]
# Buy [67.25]
# Buy [65.75]
# Sell [65.75]
# Balance: [113578.03590639]
# Balance:[113578.03590639]

# %%
plt2.figure(figsize=(18,8))
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
