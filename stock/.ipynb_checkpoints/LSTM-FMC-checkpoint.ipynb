# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2
from keras.callbacks import ModelCheckpoint
import h5py

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['JEC', 'WYNN', 'KMI', 'AN', 'FL']

# %%
SYM = 'FMC'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                  open        low       high   mv close
# date
# 2010-01-04  28.274999  27.934999  28.444999  28.410000
# 2010-01-05  28.450001  28.045000  28.495001  28.315001
# 2010-01-06  28.340000  28.155000  28.815001  28.590000
# 2010-01-07  28.540001  28.129999  28.729999  28.235001
# 2010-01-08  28.125000  27.600001  28.264999  27.985001

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.046914  0.045661  0.038382  0.052166
# 2010-01-05  0.049910  0.047623  0.039248  0.050520
# 2010-01-06  0.048027  0.049585  0.044793  0.055286
# 2010-01-07  0.051451  0.049139  0.043320  0.049133
# 2010-01-08  0.044346  0.039686  0.035263  0.044801

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 4
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.04691378 0.04566128 0.03838156 0.05216639]
#  [0.04991013 0.04762329 0.03924799 0.05051995]
#  [0.04802671 0.04958531 0.04479295 0.05528597]
#  [0.05145109 0.04913937 0.04332005 0.04913347]] 0.04480071173658701

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='auto')

model.fit(X_train, y_train, batch_size = 64, epochs = 50, validation_split = 0.05, verbose=1, callbacks=[checkpoint])

model.load_weights("weights.best.hdf5")
model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])
# Out:
# Train on 1501 samples, validate on 80 samples
# Epoch 1/50
# 1501/1501 [==============================] - 1s 915us/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 9.0684e-04 - val_mean_squared_error: 9.0684e-04
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.00091, saving model to weights.best.hdf5
# Epoch 2/50
# 1501/1501 [==============================] - 0s 234us/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 5.9089e-04 - val_mean_squared_error: 5.9089e-04
#
# Epoch 00002: val_mean_squared_error improved from 0.00091 to 0.00059, saving model to weights.best.hdf5
# Epoch 3/50
# 1501/1501 [==============================] - 0s 255us/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 5.9356e-04 - val_mean_squared_error: 5.9356e-04
#
# Epoch 00003: val_mean_squared_error did not improve
# Epoch 4/50
# 1501/1501 [==============================] - 0s 270us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 6.0251e-04 - val_mean_squared_error: 6.0251e-04
#
# Epoch 00004: val_mean_squared_error did not improve
# Epoch 5/50
# 1501/1501 [==============================] - 0s 268us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 8.3861e-04 - val_mean_squared_error: 8.3861e-04
#
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 6/50
# 1501/1501 [==============================] - 0s 246us/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 5.9132e-04 - val_mean_squared_error: 5.9132e-04
#
# Epoch 00006: val_mean_squared_error did not improve
# Epoch 7/50
# 1501/1501 [==============================] - 0s 268us/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 6.1406e-04 - val_mean_squared_error: 6.1406e-04
#
# Epoch 00007: val_mean_squared_error did not improve
# Epoch 8/50
# 1501/1501 [==============================] - 0s 253us/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 6.0242e-04 - val_mean_squared_error: 6.0242e-04
#
# Epoch 00008: val_mean_squared_error did not improve
# Epoch 9/50
# 1501/1501 [==============================] - 0s 263us/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 6.9686e-04 - val_mean_squared_error: 6.9686e-04
#
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 10/50
# 1501/1501 [==============================] - 0s 255us/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 7.6353e-04 - val_mean_squared_error: 7.6353e-04
#
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 11/50
# 1501/1501 [==============================] - 0s 300us/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 6.0074e-04 - val_mean_squared_error: 6.0074e-04
#
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 12/50
# 1501/1501 [==============================] - 0s 293us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 5.9248e-04 - val_mean_squared_error: 5.9248e-04
#
# Epoch 00012: val_mean_squared_error did not improve
# Epoch 13/50
# 1501/1501 [==============================] - 0s 327us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 6.2713e-04 - val_mean_squared_error: 6.2713e-04
#
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 14/50
# 1501/1501 [==============================] - 0s 276us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 5.9219e-04 - val_mean_squared_error: 5.9219e-04
#
# Epoch 00014: val_mean_squared_error did not improve
# Epoch 15/50
# 1501/1501 [==============================] - 0s 279us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 7.6121e-04 - val_mean_squared_error: 7.6121e-04
#
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 16/50
# 1501/1501 [==============================] - 0s 282us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 8.5302e-04 - val_mean_squared_error: 8.5302e-04
#
# Epoch 00016: val_mean_squared_error did not improve
# Epoch 17/50
# 1501/1501 [==============================] - 0s 256us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 6.0347e-04 - val_mean_squared_error: 6.0347e-04
#
# Epoch 00017: val_mean_squared_error did not improve
# Epoch 18/50
# 1501/1501 [==============================] - 0s 273us/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 5.9833e-04 - val_mean_squared_error: 5.9833e-04
#
# Epoch 00018: val_mean_squared_error did not improve
# Epoch 19/50
# 1501/1501 [==============================] - 0s 266us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 5.9321e-04 - val_mean_squared_error: 5.9321e-04
#
# Epoch 00019: val_mean_squared_error did not improve
# Epoch 20/50
# 1501/1501 [==============================] - 0s 254us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.9223e-04 - val_mean_squared_error: 5.9223e-04
#
# Epoch 00020: val_mean_squared_error did not improve
# Epoch 21/50
# 1501/1501 [==============================] - 0s 260us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 6.0405e-04 - val_mean_squared_error: 6.0405e-04
#
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 22/50
# 1501/1501 [==============================] - 0s 272us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 7.0418e-04 - val_mean_squared_error: 7.0418e-04
#
# Epoch 00022: val_mean_squared_error did not improve
# Epoch 23/50
# 1501/1501 [==============================] - 0s 265us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 8.1983e-04 - val_mean_squared_error: 8.1983e-04
#
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 24/50
# 1501/1501 [==============================] - 0s 276us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 5.9315e-04 - val_mean_squared_error: 5.9315e-04
#
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 25/50
# 1501/1501 [==============================] - 0s 271us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 6.1659e-04 - val_mean_squared_error: 6.1659e-04
#
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 26/50
# 1501/1501 [==============================] - 0s 290us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 6.4003e-04 - val_mean_squared_error: 6.4003e-04
#
# Epoch 00026: val_mean_squared_error did not improve
# Epoch 27/50
# 1501/1501 [==============================] - 0s 262us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 6.1014e-04 - val_mean_squared_error: 6.1014e-04
#
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 28/50
# 1501/1501 [==============================] - 0s 278us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 5.9885e-04 - val_mean_squared_error: 5.9885e-04
#
# Epoch 00028: val_mean_squared_error did not improve
# Epoch 29/50
# 1501/1501 [==============================] - 0s 268us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 6.6846e-04 - val_mean_squared_error: 6.6846e-04
#
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 30/50
# 1501/1501 [==============================] - 0s 277us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 6.7825e-04 - val_mean_squared_error: 6.7825e-04
#
# Epoch 00030: val_mean_squared_error did not improve
# Epoch 31/50
# 1501/1501 [==============================] - 0s 272us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.0004e-04 - val_mean_squared_error: 6.0004e-04
#
# Epoch 00031: val_mean_squared_error did not improve
# Epoch 32/50
# 1501/1501 [==============================] - 0s 284us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.4440e-04 - val_mean_squared_error: 6.4440e-04
#
# Epoch 00032: val_mean_squared_error did not improve
# Epoch 33/50
# 1501/1501 [==============================] - 0s 297us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 8.7397e-04 - val_mean_squared_error: 8.7397e-04
#
# Epoch 00033: val_mean_squared_error did not improve
# Epoch 34/50
# 1501/1501 [==============================] - 0s 279us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.8710e-04 - val_mean_squared_error: 5.8710e-04
#
# Epoch 00034: val_mean_squared_error improved from 0.00059 to 0.00059, saving model to weights.best.hdf5
# Epoch 35/50
# 1501/1501 [==============================] - 0s 299us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.2983e-04 - val_mean_squared_error: 6.2983e-04
#
# Epoch 00035: val_mean_squared_error did not improve
# Epoch 36/50
# 1501/1501 [==============================] - 0s 266us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.3778e-04 - val_mean_squared_error: 6.3778e-04
#
# Epoch 00036: val_mean_squared_error did not improve
# Epoch 37/50
# 1501/1501 [==============================] - 0s 239us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 6.7510e-04 - val_mean_squared_error: 6.7510e-04
#
# Epoch 00037: val_mean_squared_error did not improve
# Epoch 38/50
# 1501/1501 [==============================] - 0s 310us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.5476e-04 - val_mean_squared_error: 6.5476e-04
#
# Epoch 00038: val_mean_squared_error did not improve
# Epoch 39/50
# 1501/1501 [==============================] - 0s 240us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 5.8985e-04 - val_mean_squared_error: 5.8985e-04
#
# Epoch 00039: val_mean_squared_error did not improve
# Epoch 40/50
# 1501/1501 [==============================] - 0s 253us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 5.9128e-04 - val_mean_squared_error: 5.9128e-04
#
# Epoch 00040: val_mean_squared_error did not improve
# Epoch 41/50
# 1501/1501 [==============================] - 0s 261us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 5.9123e-04 - val_mean_squared_error: 5.9123e-04
#
# Epoch 00041: val_mean_squared_error did not improve
# Epoch 42/50
# 1501/1501 [==============================] - 0s 268us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 5.9587e-04 - val_mean_squared_error: 5.9587e-04
#
# Epoch 00042: val_mean_squared_error did not improve
# Epoch 43/50
# 1501/1501 [==============================] - 0s 295us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.6703e-04 - val_mean_squared_error: 6.6703e-04
#
# Epoch 00043: val_mean_squared_error did not improve
# Epoch 44/50
# 1501/1501 [==============================] - 0s 296us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.2339e-04 - val_mean_squared_error: 6.2339e-04
#
# Epoch 00044: val_mean_squared_error did not improve
# Epoch 45/50
# 1501/1501 [==============================] - 0s 262us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.0056e-04 - val_mean_squared_error: 6.0056e-04
#
# Epoch 00045: val_mean_squared_error did not improve
# Epoch 46/50
# 1501/1501 [==============================] - 0s 269us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 5.9297e-04 - val_mean_squared_error: 5.9297e-04
#
# Epoch 00046: val_mean_squared_error did not improve
# Epoch 47/50
# 1501/1501 [==============================] - 0s 265us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 8.1316e-04 - val_mean_squared_error: 8.1316e-04
#
# Epoch 00047: val_mean_squared_error did not improve
# Epoch 48/50
# 1501/1501 [==============================] - 0s 271us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.5610e-04 - val_mean_squared_error: 6.5610e-04
#
# Epoch 00048: val_mean_squared_error did not improve
# Epoch 49/50
# 1501/1501 [==============================] - 0s 261us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 5.8996e-04 - val_mean_squared_error: 5.8996e-04
#
# Epoch 00049: val_mean_squared_error did not improve
# Epoch 50/50
# 1501/1501 [==============================] - 0s 301us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.0956e-04 - val_mean_squared_error: 6.0956e-04
#
# Epoch 00050: val_mean_squared_error did not improve

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00097 (RMSE: 0.03)
# (0.0009742363789965483, 0.03121275987471387)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell : " + str(newy_test[i]))
    print("Balance : " + str(balance))
    
print("Balance : " + str(balance))
plt2.figure(figsize=(18,8))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Sell [42.669998]
# Balance: [100000.]
# Sell [47.540001]
# Balance: [100000.]
# Buy [47.]
# Buy [46.990002]
# Buy [46.]
# Buy [47.]
# Buy [47.150002]
# Buy [45.639999]
# Buy [45.709999]
# Buy [46.5]
# Buy [47.439999]
# Buy [47.330002]
# Sell [48.380001]
# Balance: [25917.51614678]
# Sell [47.849998]
# Balance: [45142.70842905]
# Sell [48.119999]
# Balance: [59642.96347709]
# Sell [47.490002]
# Balance: [70375.77450487]
# Sell [47.689999]
# Balance: [78459.28249011]
# Buy [48.009998]
# Buy [48.849998]
# Sell [49.73]
# Balance: [69915.85102155]
# Sell [50.450001]
# Balance: [78632.68030771]
# Sell [50.349998]
# Balance: [85157.34326744]
# Sell [49.66]
# Balance: [89983.77984317]
# Sell [48.389999]
# Balance: [93511.03408814]
# Buy [48.139999]
# Buy [48.580002]
# Buy [49.]
# Buy [48.290001]
# Buy [48.619999]
# Sell [48.23]
# Balance: [58571.94462691]
# Buy [48.73]
# Sell [49.299999]
# Balance: [62647.46882383]
# Sell [45.119999]
# Balance: [72309.04565809]
# Buy [42.209999]
# Buy [43.759998]
# Buy [45.349998]
# Buy [46.310001]
# Buy [46.060001]
# Sell [44.700001]
# Balance: [41992.393362]
# Sell [44.16]
# Balance: [56576.56475729]
# Sell [44.799999]
# Balance: [67673.21665819]
# Buy [46.48]
# Buy [46.419998]
# Buy [48.080002]
# Sell [48.290001]
# Balance: [54353.02678817]
# Sell [48.639999]
# Balance: [66953.55377991]
# Buy [48.860001]
# Buy [48.98]
# Sell [48.419998]
# Balance: [61310.10778858]
# Sell [48.68]
# Balance: [72135.34133892]
# Buy [47.990002]
# Buy [48.130001]
# Buy [47.950001]
# Buy [48.799999]
# Buy [48.220001]
# Sell [48.060001]
# Balance: [42610.40276454]
# Sell [47.540001]
# Balance: [57800.54665337]
# Buy [47.259998]
# Buy [46.650002]
# Buy [48.200001]
# Buy [48.389999]
# Sell [48.450001]
# Balance: [39586.7087953]
# Sell [47.919998]
# Balance: [55747.58843494]
# Sell [47.880001]
# Balance: [67858.13151093]
# Buy [48.349998]
# Buy [47.650002]
# Buy [48.290001]
# Buy [47.529999]
# Sell [47.]
# Balance: [46575.53382712]
# Buy [47.549999]
# Buy [47.810001]
# Buy [47.580002]
# Buy [48.189999]
# Sell [47.009998]
# Balance: [30455.18231676]
# Sell [47.169998]
# Balance: [48425.87503244]
# Buy [46.560001]
# Buy [47.23]
# Buy [47.400002]
# Buy [46.939999]
# Buy [46.700001]
# Sell [46.709999]
# Balance: [25385.38927051]
# Buy [46.91]
# Sell [47.389999]
# Balance: [37227.18074461]
# Sell [44.860001]
# Balance: [52733.97766451]
# Buy [46.110001]
# Buy [44.919998]
# Buy [46.5]
# Buy [47.43]
# Sell [47.779999]
# Balance: [35458.07560817]
# Sell [47.34]
# Balance: [52344.20190319]
# Sell [48.580002]
# Balance: [65340.52714375]
# Sell [48.900002]
# Balance: [75151.97687757]
# Sell [48.59]
# Balance: [82463.91434794]
# Sell [48.029999]
# Balance: [87884.66475013]
# Buy [48.349998]
# Sell [48.540001]
# Balance: [84503.22169979]
# Buy [48.240002]
# Buy [48.34]
# Sell [48.110001]
# Balance: [74404.53362938]
# Sell [47.220001]
# Balance: [81693.1422788]
# Buy [47.779999]
# Buy [48.049999]
# Buy [47.700001]
# Buy [47.84]
# Sell [47.25]
# Balance: [57039.30024927]
# Buy [47.009998]
# Buy [46.360001]
# Buy [46.560001]
# Buy [46.41]
# Buy [47.220001]
# Buy [47.919998]
# Sell [48.09]
# Balance: [26349.73912556]
# Sell [47.450001]
# Balance: [45849.0396224]
# Sell [47.849998]
# Balance: [60596.79731647]
# Sell [47.34]
# Balance: [71539.72644529]
# Buy [47.169998]
# Buy [46.990002]
# Buy [47.150002]
# Buy [46.889999]
# Buy [47.200001]
# Buy [46.09]
# Buy [50.93]
# Buy [52.459999]
# Sell [53.59]
# Balance: [29449.88114857]
# Sell [53.360001]
# Balance: [51442.49666739]
# Sell [54.25]
# Balance: [68212.07176395]
# Sell [54.099998]
# Balance: [80754.47700613]
# Sell [52.389999]
# Balance: [89863.94959006]
# Sell [52.759998]
# Balance: [96744.30506558]
# Buy [54.]
# Buy [53.5]
# Buy [53.799999]
# Sell [54.02]
# Balance: [79563.25604534]
# Sell [54.459999]
# Balance: [89255.77813261]
# Sell [54.549999]
# Balance: [96537.18301523]
# Sell [55.290001]
# Balance: [102072.31899994]
# Sell [55.110001]
# Balance: [106210.15600667]
# Sell [55.139999]
# Balance: [109315.22302181]
# Sell [54.799999]
# Balance: [111629.66361499]
# Sell [56.119999]
# Balance: [113407.30603486]
# Sell [56.34]
# Balance: [114745.76437039]
# Sell [56.529999]
# Balance: [115752.99344879]
# Sell [56.91]
# Balance: [116513.4932878]
# Buy [56.639999]
# Sell [58.220001]
# Balance: [109666.73631334]
# Sell [59.]
# Balance: [112063.35262189]
# Sell [58.810001]
# Balance: [113855.02644608]
# Buy [58.77]
# Sell [58.07]
# Balance: [107652.09636305]
# Sell [57.279999]
# Balance: [110461.15647645]
# Buy [58.290001]
# Buy [57.48]
# Buy [57.139999]
# Buy [57.02]
# Buy [57.18]
# Buy [56.98]
# Buy [56.689999]
# Buy [57.32]
# Buy [56.66]
# Sell : [56.66]
# Balance : [117960.15065798]
# Balance : [117960.15065798]

# %%
plt2.figure(figsize=(18,8))
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
