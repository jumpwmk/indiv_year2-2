# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['MKC', 'LNT', 'SPGI', 'DD', 'NEE']

# %%
SYM = 'GOOG'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                   open         low        high    mv close
# date
# 2010-01-04  312.304948  310.955001  313.580158  312.205308
# 2010-01-05  312.419511  309.610028  312.748278  310.830459
# 2010-01-06  311.761979  302.048370  311.761979  302.994813
# 2010-01-07  303.562685  295.218951  303.861575  295.941242
# 2010-01-08  294.895159  293.455551  300.499172  299.886470

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.157047  0.161167  0.156390  0.159399
# 2010-01-05  0.157238  0.158884  0.154995  0.157092
# 2010-01-06  0.156140  0.146049  0.153341  0.143942
# 2010-01-07  0.142436  0.134457  0.140094  0.132105
# 2010-01-08  0.127950  0.131464  0.134455  0.138726

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 7
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.15704696 0.16116746 0.15638998 0.15939908]
#  [0.15723843 0.15888449 0.15499506 0.15709185]
#  [0.15613951 0.14604929 0.15334121 0.14394234]
#  [0.14243617 0.13445699 0.14009362 0.13210528]
#  [0.12795029 0.13146379 0.13445546 0.13872603]
#  [0.13832355 0.1356323  0.13546617 0.1379653 ]
#  [0.13265404 0.13052526 0.13020388 0.12907917]] 0.12624526774310008

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
bestVal = 10000 
saveModel = 0
for loop in range(0, 30):
    print(loop)
    b = model.fit(X_train, y_train, batch_size = 32, epochs = 1, validation_split = 0.1, verbose = 1)
#     print(b.history)
    if(b.history['val_mean_squared_error'][0] < bestVal):
        print("===================")
        bestVal = b.history['val_mean_squared_error'][0]
        model.save('my_model_GOOG.h5')

model = load_model('my_model_GOOG.h5')
# Out:
# 0
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 2s 1ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0149 - val_mean_squared_error: 0.0149
# ===================
# 1
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 711us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0024 - val_mean_squared_error: 0.0024
# ===================
# 2
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 825us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0093 - val_mean_squared_error: 0.0093
# 3
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 911us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0136 - val_mean_squared_error: 0.0136
# 4
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 2s 1ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0110 - val_mean_squared_error: 0.0110
# 5
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 823us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
# 6
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 748us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# 7
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 830us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0129 - val_mean_squared_error: 0.0129
# 8
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 823us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# 9
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 791us/step - loss: 9.6858e-04 - mean_squared_error: 9.6858e-04 - val_loss: 0.0169 - val_mean_squared_error: 0.0169
# 10
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 854us/step - loss: 0.0010 - mean_squared_error: 0.0010 - val_loss: 0.0120 - val_mean_squared_error: 0.0120
# 11
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 843us/step - loss: 8.9271e-04 - mean_squared_error: 8.9271e-04 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# 12
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 851us/step - loss: 9.2531e-04 - mean_squared_error: 9.2531e-04 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# 13
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 744us/step - loss: 8.3706e-04 - mean_squared_error: 8.3706e-04 - val_loss: 0.0270 - val_mean_squared_error: 0.0270
# 14
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 693us/step - loss: 8.1514e-04 - mean_squared_error: 8.1514e-04 - val_loss: 0.0210 - val_mean_squared_error: 0.0210
# 15
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 652us/step - loss: 8.5804e-04 - mean_squared_error: 8.5804e-04 - val_loss: 0.0127 - val_mean_squared_error: 0.0127
# 16
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 662us/step - loss: 8.2929e-04 - mean_squared_error: 8.2929e-04 - val_loss: 0.0174 - val_mean_squared_error: 0.0174
# 17
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 653us/step - loss: 7.5402e-04 - mean_squared_error: 7.5402e-04 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# 18
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 656us/step - loss: 8.7534e-04 - mean_squared_error: 8.7534e-04 - val_loss: 0.0118 - val_mean_squared_error: 0.0118
# 19
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 787us/step - loss: 8.4878e-04 - mean_squared_error: 8.4878e-04 - val_loss: 0.0111 - val_mean_squared_error: 0.0111
# 20
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 796us/step - loss: 8.0164e-04 - mean_squared_error: 8.0164e-04 - val_loss: 0.0138 - val_mean_squared_error: 0.0138
# 21
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 755us/step - loss: 7.7349e-04 - mean_squared_error: 7.7349e-04 - val_loss: 0.0086 - val_mean_squared_error: 0.0086
# 22
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 659us/step - loss: 7.6709e-04 - mean_squared_error: 7.6709e-04 - val_loss: 0.0139 - val_mean_squared_error: 0.0139
# 23
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 767us/step - loss: 7.7403e-04 - mean_squared_error: 7.7403e-04 - val_loss: 0.0116 - val_mean_squared_error: 0.0116
# 24
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 794us/step - loss: 7.7224e-04 - mean_squared_error: 7.7224e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
# 25
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 832us/step - loss: 7.9619e-04 - mean_squared_error: 7.9619e-04 - val_loss: 0.0209 - val_mean_squared_error: 0.0209
# 26
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 777us/step - loss: 7.7936e-04 - mean_squared_error: 7.7936e-04 - val_loss: 0.0177 - val_mean_squared_error: 0.0177
# 27
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 609us/step - loss: 7.4517e-04 - mean_squared_error: 7.4517e-04 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# 28
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 613us/step - loss: 7.2799e-04 - mean_squared_error: 7.2799e-04 - val_loss: 0.0203 - val_mean_squared_error: 0.0203
# 29
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 634us/step - loss: 7.1778e-04 - mean_squared_error: 7.1778e-04 - val_loss: 0.0141 - val_mean_squared_error: 0.0141
# 30
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 622us/step - loss: 6.8672e-04 - mean_squared_error: 6.8672e-04 - val_loss: 0.0242 - val_mean_squared_error: 0.0242
# 31
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 621us/step - loss: 6.7343e-04 - mean_squared_error: 6.7343e-04 - val_loss: 0.0204 - val_mean_squared_error: 0.0204
# 32
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 620us/step - loss: 6.7338e-04 - mean_squared_error: 6.7338e-04 - val_loss: 0.0273 - val_mean_squared_error: 0.0273
# 33
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 618us/step - loss: 6.7839e-04 - mean_squared_error: 6.7839e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# 34
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 625us/step - loss: 6.7975e-04 - mean_squared_error: 6.7975e-04 - val_loss: 0.0316 - val_mean_squared_error: 0.0316
# 35
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 644us/step - loss: 6.6796e-04 - mean_squared_error: 6.6796e-04 - val_loss: 0.0234 - val_mean_squared_error: 0.0234
# 36
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 631us/step - loss: 6.7915e-04 - mean_squared_error: 6.7915e-04 - val_loss: 0.0244 - val_mean_squared_error: 0.0244
# 37
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 567us/step - loss: 7.0661e-04 - mean_squared_error: 7.0661e-04 - val_loss: 0.0144 - val_mean_squared_error: 0.0144
# 38
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 571us/step - loss: 6.3863e-04 - mean_squared_error: 6.3863e-04 - val_loss: 0.0304 - val_mean_squared_error: 0.0304
# 39
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 565us/step - loss: 6.3226e-04 - mean_squared_error: 6.3226e-04 - val_loss: 0.0200 - val_mean_squared_error: 0.0200
# 40
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 595us/step - loss: 6.3132e-04 - mean_squared_error: 6.3132e-04 - val_loss: 0.0164 - val_mean_squared_error: 0.0164
# 41
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 574us/step - loss: 7.0512e-04 - mean_squared_error: 7.0512e-04 - val_loss: 0.0281 - val_mean_squared_error: 0.0281
# 42
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 572us/step - loss: 6.4470e-04 - mean_squared_error: 6.4470e-04 - val_loss: 0.0146 - val_mean_squared_error: 0.0146
# 43
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 598us/step - loss: 6.6773e-04 - mean_squared_error: 6.6773e-04 - val_loss: 0.0185 - val_mean_squared_error: 0.0185
# 44
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 602us/step - loss: 6.4043e-04 - mean_squared_error: 6.4043e-04 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# 45
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 580us/step - loss: 6.0547e-04 - mean_squared_error: 6.0547e-04 - val_loss: 0.0274 - val_mean_squared_error: 0.0274
# 46
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 587us/step - loss: 6.4592e-04 - mean_squared_error: 6.4592e-04 - val_loss: 0.0148 - val_mean_squared_error: 0.0148
# 47
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 596us/step - loss: 6.7062e-04 - mean_squared_error: 6.7062e-04 - val_loss: 0.0271 - val_mean_squared_error: 0.0271
# 48
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 590us/step - loss: 7.0012e-04 - mean_squared_error: 7.0012e-04 - val_loss: 0.0250 - val_mean_squared_error: 0.0250
# 49
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 591us/step - loss: 6.1506e-04 - mean_squared_error: 6.1506e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# 50
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 584us/step - loss: 5.9675e-04 - mean_squared_error: 5.9675e-04 - val_loss: 0.0221 - val_mean_squared_error: 0.0221
# 51
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 596us/step - loss: 6.1413e-04 - mean_squared_error: 6.1413e-04 - val_loss: 0.0202 - val_mean_squared_error: 0.0202
# 52
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 608us/step - loss: 5.8658e-04 - mean_squared_error: 5.8658e-04 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
# 53
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 604us/step - loss: 6.2265e-04 - mean_squared_error: 6.2265e-04 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# 54
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 619us/step - loss: 5.4663e-04 - mean_squared_error: 5.4663e-04 - val_loss: 0.0182 - val_mean_squared_error: 0.0182
# 55
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 607us/step - loss: 5.9462e-04 - mean_squared_error: 5.9462e-04 - val_loss: 0.0267 - val_mean_squared_error: 0.0267
# 56
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 609us/step - loss: 5.8193e-04 - mean_squared_error: 5.8193e-04 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# 57
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 598us/step - loss: 5.3371e-04 - mean_squared_error: 5.3371e-04 - val_loss: 0.0276 - val_mean_squared_error: 0.0276
# 58
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 600us/step - loss: 6.2266e-04 - mean_squared_error: 6.2266e-04 - val_loss: 0.0324 - val_mean_squared_error: 0.0324
# 59
# Train on 1421 samples, validate on 158 samples
# Epoch 1/1
# 1421/1421 [==============================] - 1s 616us/step - loss: 5.9804e-04 - mean_squared_error: 5.9804e-04 - val_loss: 0.0260 - val_mean_squared_error: 0.0260

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00316 (RMSE: 0.06)
# (0.003155091399593013, 0.056170200280869685)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell " + str(newy_test[i]))
    print("Balance: " + str(balance))
    
print("Balance:" + str(balance))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Buy [708.140015]
# Buy [705.840027]
# Buy [691.02002]
# Buy [693.01001]
# Buy [698.210022]
# Buy [692.359985]
# Buy [695.700012]
# Buy [701.429993]
# Buy [711.119995]
# Buy [712.900024]
# Sell [723.179993]
# Balance: [25795.10970934]
# Sell [715.289978]
# Balance: [44930.3702618]
# Sell [713.309998]
# Balance: [59242.08972475]
# Sell [710.830017]
# Balance: [69938.56091296]
# Sell [716.48999]
# Balance: [78024.79216872]
# Sell [706.22998]
# Balance: [84002.62055894]
# Sell [706.630005]
# Balance: [88488.53133683]
# Buy [700.320007]
# Buy [709.73999]
# Buy [704.23999]
# Buy [720.090027]
# Buy [725.27002]
# Sell [724.119995]
# Balance: [54652.45151732]
# Sell [732.659973]
# Balance: [66918.36469965]
# Sell [735.719971]
# Balance: [76156.22157394]
# Sell [734.150024]
# Balance: [83069.82978762]
# Sell [730.400024]
# Balance: [88228.55018548]
# Sell [722.340027]
# Balance: [92054.89545078]
# Sell [716.549988]
# Balance: [94901.65136017]
# Sell [716.650024]
# Balance: [97037.01636431]
# Buy [728.280029]
# Buy [728.580017]
# Buy [719.409973]
# Buy [718.359985]
# Buy [718.27002]
# Buy [718.919983]
# Buy [710.359985]
# Buy [691.719971]
# Buy [693.710022]
# Buy [695.940002]
# Sell [695.359985]
# Balance: [25225.76299907]
# Sell [705.630005]
# Balance: [44424.51147662]
# Sell [715.090027]
# Balance: [59016.61371494]
# Sell [720.640015]
# Balance: [70045.63004036]
# Buy [716.97998]
# Sell [720.950012]
# Balance: [70834.79343716]
# Sell [719.849976]
# Balance: [78914.3192881]
# Buy [733.780029]
# Buy [736.960022]
# Sell [741.190002]
# Balance: [70193.19776765]
# Sell [738.630005]
# Balance: [78623.1395288]
# Sell [742.73999]
# Balance: [84980.77611646]
# Buy [739.77002]
# Sell [738.419983]
# Balance: [82216.70770833]
# Sell [741.77002]
# Balance: [87668.27718626]
# Sell [745.909973]
# Balance: [91779.77394312]
# Sell [768.789978]
# Balance: [94957.98339432]
# Sell [772.880005]
# Balance: [97354.32173786]
# Sell [771.070007]
# Balance: [99147.36652945]
# Sell [773.179993]
# Balance: [100495.83004135]
# Buy [771.609985]
# Sell [782.219971]
# Balance: [94053.37842605]
# Sell [781.76001]
# Balance: [96719.97078233]
# Sell [784.26001]
# Balance: [98726.31069604]
# Sell [784.679993]
# Balance: [100231.87145016]
# Sell [784.849976]
# Balance: [101361.28662476]
# Sell [783.219971]
# Balance: [102206.5887978]
# Sell [782.440002]
# Balance: [102839.93408245]
# Sell [777.140015]
# Balance: [103311.72549402]
# Sell [779.909973]
# Balance: [103666.8302563]
# Buy [777.5]
# Buy [775.419983]
# Buy [772.150024]
# Buy [772.080017]
# Buy [769.640015]
# Buy [769.409973]
# Buy [769.539978]
# Buy [772.150024]
# Buy [769.090027]
# Buy [767.049988]
# Buy [768.780029]
# Sell [780.349976]
# Balance: [26487.32082271]
# Sell [775.320007]
# Balance: [46224.76273717]
# Sell [759.659973]
# Balance: [60728.84923351]
# Sell [769.02002]
# Balance: [71740.94670205]
# Buy [759.690002]
# Buy [762.48999]
# Buy [771.76001]
# Buy [768.880005]
# Buy [765.700012]
# Buy [771.409973]
# Sell [776.219971]
# Balance: [35265.00839096]
# Sell [787.210022]
# Balance: [53157.85237673]
# Sell [786.900024]
# Balance: [66572.20080505]
# Sell [774.210022]
# Balance: [76470.71650754]
# Sell [783.01001]
# Balance: [83978.98622016]
# Buy [781.559998]
# Sell [775.01001]
# Balance: [82031.7029583]
# Sell [777.289978]
# Balance: [88089.00796288]
# Sell [772.559998]
# Balance: [92604.34169418]
# Buy [776.429993]
# Buy [776.469971]
# Buy [776.859985]
# Buy [775.080017]
# Buy [785.940002]
# Sell [783.070007]
# Balance: [58616.16916452]
# Sell [786.140015]
# Balance: [70672.120269]
# Sell [778.190002]
# Balance: [79622.64476378]
# Sell [778.530029]
# Balance: [86338.47130669]
# Sell [779.960022]
# Balance: [91384.59286564]
# Sell [795.26001]
# Balance: [95243.4239931]
# Sell [801.5]
# Balance: [98160.25601322]
# Sell [796.969971]
# Balance: [100335.51571113]
# Sell [799.369995]
# Balance: [101971.87347595]
# Sell [813.109985]
# Balance: [103220.23673008]
# Sell [807.669983]
# Balance: [104150.24516698]
# Sell [799.070007]
# Balance: [104840.32452844]
# Sell [795.349976]
# Balance: [105355.47457671]
# Sell [795.369995]
# Balance: [105741.84683768]
# Sell [784.539978]
# Balance: [106027.68030547]
# Buy [783.609985]
# Buy [768.700012]
# Buy [762.130005]
# Buy [762.02002]
# Buy [782.52002]
# Buy [790.51001]
# Buy [785.309998]
# Buy [762.559998]
# Buy [754.02002]
# Buy [736.080017]
# Buy [758.48999]
# Sell [771.22998]
# Balance: [26834.76757609]
# Buy [760.539978]
# Buy [769.200012]
# Buy [768.27002]
# Sell [760.98999]
# Balance: [26526.14828921]
# Sell [761.679993]
# Balance: [46438.79829979]
# Sell [768.23999]
# Balance: [61501.90963158]
# Sell [770.840027]
# Balance: [72837.47790794]
# Buy [758.039978]
# Sell [747.919983]
# Balance: [73552.99099321]
# Buy [750.5]
# Buy [762.52002]
# Buy [759.109985]
# Buy [771.190002]
# Buy [776.419983]
# Buy [789.289978]
# Sell [789.27002]
# Balance: [37450.0452859]
# Buy [796.099976]
# Sell [797.070007]
# Balance: [48053.00477291]
# Sell [797.849976]
# Balance: [63520.34508293]
# Sell [790.799988]
# Balance: [75018.34555247]
# Sell [794.200012]
# Balance: [83678.92242031]
# Buy [796.419983]
# Sell [794.559998]
# Balance: [82671.46066655]
# Buy [791.26001]
# Buy [789.909973]
# Buy [791.549988]
# Buy [785.049988]
# Sell [785.049988]
# Balance: [109104.05713146]
# Balance:[109104.05713146]

# %%
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
