# %%
#import sys
#sys.path.append('/home/itsara/env/lib/python2.7/site-packages')

import numpy as np
import pandas as pd
import math
import itertools
from sklearn import preprocessing
from operator import itemgetter
from sklearn.metrics import mean_squared_error
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
import keras
import matplotlib.pyplot as plt2
from keras.callbacks import ModelCheckpoint
import h5py

from keras.models import load_model
# Out:
# /usr/local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume','close'], 1, inplace=True)
df.head()
# Out:
#            symbol        open         low        high    mv close
# date
# 2016-01-05   WLTW  123.430000  122.309998  126.250000  125.839996
# 2016-01-06   WLTW  125.239998  119.940002  125.540001  119.980003
# 2016-01-07   WLTW  116.379997  114.930000  119.739998  114.949997
# 2016-01-08   WLTW  115.480003  113.500000  117.440002  116.620003
# 2016-01-11   WLTW  117.010002  114.089996  117.330002  114.970001

# %%
symbols = list(set(df.symbol))
symbols[:5]
# Out:
# ['TXN', 'TGT', 'GT', 'PBCT', 'BK']

# %%
SYM = 'GOOG'
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)
df.head()
# Out:
#                   open         low        high    mv close
# date
# 2010-01-04  312.304948  310.955001  313.580158  312.205308
# 2010-01-05  312.419511  309.610028  312.748278  310.830459
# 2010-01-06  311.761979  302.048370  311.761979  302.994813
# 2010-01-07  303.562685  295.218951  303.861575  295.941242
# 2010-01-08  294.895159  293.455551  300.499172  299.886470

# %%
def normalize_data(df):
    min_max_scaler = preprocessing.MinMaxScaler()
    df['open'] = min_max_scaler.fit_transform(df.open.values.reshape(-1,1))
    df['high'] = min_max_scaler.fit_transform(df.high.values.reshape(-1,1))
    df['low'] = min_max_scaler.fit_transform(df.low.values.reshape(-1,1))
#    df['volume'] = min_max_scaler.fit_transform(df.volume.values.reshape(-1,1))
    df['mv close'] = min_max_scaler.fit_transform(df['mv close'].values.reshape(-1,1))
    return df
df = normalize_data(df)
df.head()
# Out:
#                 open       low      high  mv close
# date
# 2010-01-04  0.157047  0.161167  0.156390  0.159399
# 2010-01-05  0.157238  0.158884  0.154995  0.157092
# 2010-01-06  0.156140  0.146049  0.153341  0.143942
# 2010-01-07  0.142436  0.134457  0.140094  0.132105
# 2010-01-08  0.127950  0.131464  0.134455  0.138726

# %%
def load_data(stock, seq_len):
    n_features = len(stock.columns)
    data = stock.as_matrix() 
    sequence_length = seq_len + 1
    result = []
    
    for index in range(len(data) - sequence_length):
        result.append(data[index: index + sequence_length])
    
    result = np.array(result)
    row = round(0.9 * result.shape[0])
    train = result[:int(row), :]

    x_train = train[:, :-1]
    y_train = train[:, -1][:,-1]
    
    x_test = result[int(row):, :-1] 
    y_test = result[int(row):, -1][:,-1]

    x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], n_features))
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], n_features))  

    return [x_train, y_train, x_test, y_test]

# %%
n_features = 4
prev_days = 7
X_train, y_train, X_test, y_test = load_data(df, prev_days)
print (X_train[0], y_train[0])
# Out:
# [[0.15704696 0.16116746 0.15638998 0.15939908]
#  [0.15723843 0.15888449 0.15499506 0.15709185]
#  [0.15613951 0.14604929 0.15334121 0.14394234]
#  [0.14243617 0.13445699 0.14009362 0.13210528]
#  [0.12795029 0.13146379 0.13445546 0.13872603]
#  [0.13832355 0.1356323  0.13546617 0.1379653 ]
#  [0.13265404 0.13052526 0.13020388 0.12907917]] 0.12624526774310008

# %%
def build_model(layers):
    p = 0.25
    model = Sequential()

    model.add(LSTM(128, input_shape=(layers[1], layers[0]), return_sequences=True))
    model.add(Dropout(p))

    model.add(LSTM(64, input_shape=(layers[1], layers[0]), return_sequences=False))
    model.add(Dropout(p))

    model.add(Dense(64,activation='relu'))
    model.add(Dense(1,activation='linear'))

    model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])

    return model

model = build_model([n_features, prev_days, 1])

# %%
checkpoint = ModelCheckpoint("weights.best.hdf5", monitor='val_mean_squared_error', verbose=1, save_best_only=True, mode='auto')

model.fit(X_train, y_train, batch_size = 64, epochs = 100, validation_split = 0.1, verbose=1, callbacks=[checkpoint])

model.load_weights("weights.best.hdf5")
model.compile(loss='mse',optimizer='adagrad', metrics=['mse'])
# Out:
# Train on 1421 samples, validate on 158 samples
# Epoch 1/100
# 1421/1421 [==============================] - 2s 1ms/step - loss: 0.0266 - mean_squared_error: 0.0266 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00001: val_mean_squared_error improved from inf to 0.00150, saving model to weights.best.hdf5
# Epoch 2/100
# 1421/1421 [==============================] - 1s 390us/step - loss: 0.0030 - mean_squared_error: 0.0030 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
#
# Epoch 00002: val_mean_squared_error did not improve
# Epoch 3/100
# 1421/1421 [==============================] - 1s 421us/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0061 - val_mean_squared_error: 0.0061
#
# Epoch 00003: val_mean_squared_error did not improve
# Epoch 4/100
# 1421/1421 [==============================] - 1s 400us/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
#
# Epoch 00004: val_mean_squared_error improved from 0.00150 to 0.00120, saving model to weights.best.hdf5
# Epoch 5/100
# 1421/1421 [==============================] - 1s 442us/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
#
# Epoch 00005: val_mean_squared_error did not improve
# Epoch 6/100
# 1421/1421 [==============================] - 1s 379us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
#
# Epoch 00006: val_mean_squared_error improved from 0.00120 to 0.00100, saving model to weights.best.hdf5
# Epoch 7/100
# 1421/1421 [==============================] - 1s 417us/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00007: val_mean_squared_error did not improve
# Epoch 8/100
# 1421/1421 [==============================] - 1s 432us/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0081 - val_mean_squared_error: 0.0081
#
# Epoch 00008: val_mean_squared_error did not improve
# Epoch 9/100
# 1421/1421 [==============================] - 1s 497us/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
#
# Epoch 00009: val_mean_squared_error did not improve
# Epoch 10/100
# 1421/1421 [==============================] - 1s 505us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0083 - val_mean_squared_error: 0.0083
#
# Epoch 00010: val_mean_squared_error did not improve
# Epoch 11/100
# 1421/1421 [==============================] - 1s 470us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
#
# Epoch 00011: val_mean_squared_error did not improve
# Epoch 12/100
# 1421/1421 [==============================] - 1s 459us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
#
# Epoch 00012: val_mean_squared_error did not improve
# Epoch 13/100
# 1421/1421 [==============================] - 1s 482us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00013: val_mean_squared_error did not improve
# Epoch 14/100
# 1421/1421 [==============================] - 1s 468us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00014: val_mean_squared_error did not improve
# Epoch 15/100
# 1421/1421 [==============================] - 1s 465us/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00015: val_mean_squared_error did not improve
# Epoch 16/100
# 1421/1421 [==============================] - 1s 426us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.9340e-04 - val_mean_squared_error: 9.9340e-04
#
# Epoch 00016: val_mean_squared_error improved from 0.00100 to 0.00099, saving model to weights.best.hdf5
# Epoch 17/100
# 1421/1421 [==============================] - 1s 468us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.3896e-04 - val_mean_squared_error: 9.3896e-04
#
# Epoch 00017: val_mean_squared_error improved from 0.00099 to 0.00094, saving model to weights.best.hdf5
# Epoch 18/100
# 1421/1421 [==============================] - 1s 494us/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00018: val_mean_squared_error did not improve
# Epoch 19/100
# 1421/1421 [==============================] - 1s 473us/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00019: val_mean_squared_error did not improve
# Epoch 20/100
# 1421/1421 [==============================] - 1s 516us/step - loss: 9.7260e-04 - mean_squared_error: 9.7260e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
#
# Epoch 00020: val_mean_squared_error did not improve
# Epoch 21/100
# 1421/1421 [==============================] - 1s 475us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00021: val_mean_squared_error did not improve
# Epoch 22/100
# 1421/1421 [==============================] - 1s 510us/step - loss: 9.6365e-04 - mean_squared_error: 9.6365e-04 - val_loss: 9.1752e-04 - val_mean_squared_error: 9.1752e-04
#
# Epoch 00022: val_mean_squared_error improved from 0.00094 to 0.00092, saving model to weights.best.hdf5
# Epoch 23/100
# 1421/1421 [==============================] - 1s 475us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00023: val_mean_squared_error did not improve
# Epoch 24/100
# 1421/1421 [==============================] - 1s 461us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
#
# Epoch 00024: val_mean_squared_error did not improve
# Epoch 25/100
# 1421/1421 [==============================] - 1s 481us/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00025: val_mean_squared_error did not improve
# Epoch 26/100
# 1421/1421 [==============================] - 1s 486us/step - loss: 9.7304e-04 - mean_squared_error: 9.7304e-04 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
#
# Epoch 00026: val_mean_squared_error did not improve
# Epoch 27/100
# 1421/1421 [==============================] - 1s 474us/step - loss: 9.3878e-04 - mean_squared_error: 9.3878e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00027: val_mean_squared_error did not improve
# Epoch 28/100
# 1421/1421 [==============================] - 1s 496us/step - loss: 9.6793e-04 - mean_squared_error: 9.6793e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00028: val_mean_squared_error did not improve
# Epoch 29/100
# 1421/1421 [==============================] - 1s 502us/step - loss: 9.4929e-04 - mean_squared_error: 9.4929e-04 - val_loss: 9.2768e-04 - val_mean_squared_error: 9.2768e-04
#
# Epoch 00029: val_mean_squared_error did not improve
# Epoch 30/100
# 1421/1421 [==============================] - 1s 467us/step - loss: 8.9935e-04 - mean_squared_error: 8.9935e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
#
# Epoch 00030: val_mean_squared_error did not improve
# Epoch 31/100
# 1421/1421 [==============================] - 1s 476us/step - loss: 9.8340e-04 - mean_squared_error: 9.8340e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
#
# Epoch 00031: val_mean_squared_error did not improve
# Epoch 32/100
# 1421/1421 [==============================] - 1s 459us/step - loss: 9.7439e-04 - mean_squared_error: 9.7439e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
#
# Epoch 00032: val_mean_squared_error did not improve
# Epoch 33/100
# 1421/1421 [==============================] - 1s 464us/step - loss: 9.1497e-04 - mean_squared_error: 9.1497e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00033: val_mean_squared_error did not improve
# Epoch 34/100
# 1421/1421 [==============================] - 1s 475us/step - loss: 9.0833e-04 - mean_squared_error: 9.0833e-04 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
#
# Epoch 00034: val_mean_squared_error did not improve
# Epoch 35/100
# 1421/1421 [==============================] - 1s 449us/step - loss: 9.0648e-04 - mean_squared_error: 9.0648e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
#
# Epoch 00035: val_mean_squared_error did not improve
# Epoch 36/100
# 1421/1421 [==============================] - 1s 367us/step - loss: 8.1333e-04 - mean_squared_error: 8.1333e-04 - val_loss: 8.9984e-04 - val_mean_squared_error: 8.9984e-04
#
# Epoch 00036: val_mean_squared_error improved from 0.00092 to 0.00090, saving model to weights.best.hdf5
# Epoch 37/100
# 1421/1421 [==============================] - 1s 418us/step - loss: 8.7911e-04 - mean_squared_error: 8.7911e-04 - val_loss: 9.1720e-04 - val_mean_squared_error: 9.1720e-04
#
# Epoch 00037: val_mean_squared_error did not improve
# Epoch 38/100
# 1421/1421 [==============================] - 1s 383us/step - loss: 8.7986e-04 - mean_squared_error: 8.7986e-04 - val_loss: 0.0054 - val_mean_squared_error: 0.0054
#
# Epoch 00038: val_mean_squared_error did not improve
# Epoch 39/100
# 1421/1421 [==============================] - 1s 399us/step - loss: 8.4233e-04 - mean_squared_error: 8.4233e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00039: val_mean_squared_error did not improve
# Epoch 40/100
# 1421/1421 [==============================] - 1s 413us/step - loss: 8.2490e-04 - mean_squared_error: 8.2490e-04 - val_loss: 9.3531e-04 - val_mean_squared_error: 9.3531e-04
#
# Epoch 00040: val_mean_squared_error did not improve
# Epoch 41/100
# 1421/1421 [==============================] - 1s 388us/step - loss: 9.6727e-04 - mean_squared_error: 9.6727e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00041: val_mean_squared_error did not improve
# Epoch 42/100
# 1421/1421 [==============================] - 1s 407us/step - loss: 8.3234e-04 - mean_squared_error: 8.3234e-04 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
#
# Epoch 00042: val_mean_squared_error did not improve
# Epoch 43/100
# 1421/1421 [==============================] - 1s 586us/step - loss: 8.2126e-04 - mean_squared_error: 8.2126e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
#
# Epoch 00043: val_mean_squared_error did not improve
# Epoch 44/100
# 1421/1421 [==============================] - 1s 426us/step - loss: 8.0766e-04 - mean_squared_error: 8.0766e-04 - val_loss: 0.0052 - val_mean_squared_error: 0.0052
#
# Epoch 00044: val_mean_squared_error did not improve
# Epoch 45/100
# 1421/1421 [==============================] - 1s 398us/step - loss: 8.3334e-04 - mean_squared_error: 8.3334e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
#
# Epoch 00045: val_mean_squared_error did not improve
# Epoch 46/100
# 1421/1421 [==============================] - 1s 437us/step - loss: 8.4473e-04 - mean_squared_error: 8.4473e-04 - val_loss: 0.0075 - val_mean_squared_error: 0.0075
#
# Epoch 00046: val_mean_squared_error did not improve
# Epoch 47/100
# 1421/1421 [==============================] - 1s 391us/step - loss: 8.2323e-04 - mean_squared_error: 8.2323e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
#
# Epoch 00047: val_mean_squared_error did not improve
# Epoch 48/100
# 1421/1421 [==============================] - 1s 404us/step - loss: 8.3970e-04 - mean_squared_error: 8.3970e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00048: val_mean_squared_error did not improve
# Epoch 49/100
# 1421/1421 [==============================] - 1s 397us/step - loss: 7.7314e-04 - mean_squared_error: 7.7314e-04 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
#
# Epoch 00049: val_mean_squared_error did not improve
# Epoch 50/100
# 1421/1421 [==============================] - 1s 400us/step - loss: 7.9862e-04 - mean_squared_error: 7.9862e-04 - val_loss: 0.0049 - val_mean_squared_error: 0.0049
#
# Epoch 00050: val_mean_squared_error did not improve
# Epoch 51/100
# 1421/1421 [==============================] - 1s 393us/step - loss: 7.4387e-04 - mean_squared_error: 7.4387e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00051: val_mean_squared_error did not improve
# Epoch 52/100
# 1421/1421 [==============================] - 1s 405us/step - loss: 7.3465e-04 - mean_squared_error: 7.3465e-04 - val_loss: 0.0030 - val_mean_squared_error: 0.0030
#
# Epoch 00052: val_mean_squared_error did not improve
# Epoch 53/100
# 1421/1421 [==============================] - 1s 424us/step - loss: 7.7347e-04 - mean_squared_error: 7.7347e-04 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
#
# Epoch 00053: val_mean_squared_error did not improve
# Epoch 54/100
# 1421/1421 [==============================] - 1s 419us/step - loss: 9.7458e-04 - mean_squared_error: 9.7458e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00054: val_mean_squared_error did not improve
# Epoch 55/100
# 1421/1421 [==============================] - 1s 428us/step - loss: 7.6612e-04 - mean_squared_error: 7.6612e-04 - val_loss: 0.0026 - val_mean_squared_error: 0.0026
#
# Epoch 00055: val_mean_squared_error did not improve
# Epoch 56/100
# 1421/1421 [==============================] - 1s 442us/step - loss: 7.5682e-04 - mean_squared_error: 7.5682e-04 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
#
# Epoch 00056: val_mean_squared_error did not improve
# Epoch 57/100
# 1421/1421 [==============================] - 1s 431us/step - loss: 7.7879e-04 - mean_squared_error: 7.7879e-04 - val_loss: 0.0035 - val_mean_squared_error: 0.0035
#
# Epoch 00057: val_mean_squared_error did not improve
# Epoch 58/100
# 1421/1421 [==============================] - 1s 437us/step - loss: 7.6380e-04 - mean_squared_error: 7.6380e-04 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
#
# Epoch 00058: val_mean_squared_error did not improve
# Epoch 59/100
# 1421/1421 [==============================] - 1s 418us/step - loss: 6.9224e-04 - mean_squared_error: 6.9224e-04 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
#
# Epoch 00059: val_mean_squared_error did not improve
# Epoch 60/100
# 1421/1421 [==============================] - 1s 465us/step - loss: 7.6014e-04 - mean_squared_error: 7.6014e-04 - val_loss: 9.7101e-04 - val_mean_squared_error: 9.7101e-04
#
# Epoch 00060: val_mean_squared_error did not improve
# Epoch 61/100
# 1421/1421 [==============================] - 1s 447us/step - loss: 7.5826e-04 - mean_squared_error: 7.5826e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
#
# Epoch 00061: val_mean_squared_error did not improve
# Epoch 62/100
# 1421/1421 [==============================] - 1s 452us/step - loss: 7.3853e-04 - mean_squared_error: 7.3853e-04 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
#
# Epoch 00062: val_mean_squared_error did not improve
# Epoch 63/100
# 1421/1421 [==============================] - 1s 453us/step - loss: 8.1138e-04 - mean_squared_error: 8.1138e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00063: val_mean_squared_error did not improve
# Epoch 64/100
# 1421/1421 [==============================] - 1s 442us/step - loss: 7.7960e-04 - mean_squared_error: 7.7960e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
#
# Epoch 00064: val_mean_squared_error did not improve
# Epoch 65/100
# 1421/1421 [==============================] - 1s 424us/step - loss: 7.6213e-04 - mean_squared_error: 7.6213e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# Epoch 00065: val_mean_squared_error did not improve
# Epoch 66/100
# 1421/1421 [==============================] - 1s 435us/step - loss: 6.7796e-04 - mean_squared_error: 6.7796e-04 - val_loss: 9.3717e-04 - val_mean_squared_error: 9.3717e-04
#
# Epoch 00066: val_mean_squared_error did not improve
# Epoch 67/100
# 1421/1421 [==============================] - 1s 462us/step - loss: 7.0625e-04 - mean_squared_error: 7.0625e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
#
# Epoch 00067: val_mean_squared_error did not improve
# Epoch 68/100
# 1421/1421 [==============================] - 1s 458us/step - loss: 7.6461e-04 - mean_squared_error: 7.6461e-04 - val_loss: 8.6766e-04 - val_mean_squared_error: 8.6766e-04
#
# Epoch 00068: val_mean_squared_error improved from 0.00090 to 0.00087, saving model to weights.best.hdf5
# Epoch 69/100
# 1421/1421 [==============================] - 1s 491us/step - loss: 7.3417e-04 - mean_squared_error: 7.3417e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
#
# Epoch 00069: val_mean_squared_error did not improve
# Epoch 70/100
# 1421/1421 [==============================] - 1s 466us/step - loss: 7.5189e-04 - mean_squared_error: 7.5189e-04 - val_loss: 8.8099e-04 - val_mean_squared_error: 8.8099e-04
#
# Epoch 00070: val_mean_squared_error did not improve
# Epoch 71/100
# 1421/1421 [==============================] - 1s 446us/step - loss: 7.6942e-04 - mean_squared_error: 7.6942e-04 - val_loss: 0.0089 - val_mean_squared_error: 0.0089
#
# Epoch 00071: val_mean_squared_error did not improve
# Epoch 72/100
# 1421/1421 [==============================] - 1s 401us/step - loss: 7.6619e-04 - mean_squared_error: 7.6619e-04 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
#
# Epoch 00072: val_mean_squared_error did not improve
# Epoch 73/100
# 1421/1421 [==============================] - 1s 434us/step - loss: 7.9266e-04 - mean_squared_error: 7.9266e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00073: val_mean_squared_error did not improve
# Epoch 74/100
# 1421/1421 [==============================] - 1s 444us/step - loss: 7.4988e-04 - mean_squared_error: 7.4988e-04 - val_loss: 0.0073 - val_mean_squared_error: 0.0073
#
# Epoch 00074: val_mean_squared_error did not improve
# Epoch 75/100
# 1421/1421 [==============================] - 1s 424us/step - loss: 8.0566e-04 - mean_squared_error: 8.0566e-04 - val_loss: 8.5463e-04 - val_mean_squared_error: 8.5463e-04
#
# Epoch 00075: val_mean_squared_error improved from 0.00087 to 0.00085, saving model to weights.best.hdf5
# Epoch 76/100
# 1421/1421 [==============================] - 1s 405us/step - loss: 7.0311e-04 - mean_squared_error: 7.0311e-04 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
#
# Epoch 00076: val_mean_squared_error did not improve
# Epoch 77/100
# 1421/1421 [==============================] - 1s 398us/step - loss: 6.8907e-04 - mean_squared_error: 6.8907e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
#
# Epoch 00077: val_mean_squared_error did not improve
# Epoch 78/100
# 1421/1421 [==============================] - 1s 393us/step - loss: 6.7763e-04 - mean_squared_error: 6.7763e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
#
# Epoch 00078: val_mean_squared_error did not improve
# Epoch 79/100
# 1421/1421 [==============================] - 1s 409us/step - loss: 7.0304e-04 - mean_squared_error: 7.0304e-04 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
#
# Epoch 00079: val_mean_squared_error did not improve
# Epoch 80/100
# 1421/1421 [==============================] - 1s 421us/step - loss: 6.4830e-04 - mean_squared_error: 6.4830e-04 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
#
# Epoch 00080: val_mean_squared_error did not improve
# Epoch 81/100
# 1421/1421 [==============================] - 1s 409us/step - loss: 6.9881e-04 - mean_squared_error: 6.9881e-04 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
#
# Epoch 00081: val_mean_squared_error did not improve
# Epoch 82/100
# 1421/1421 [==============================] - 1s 432us/step - loss: 7.7402e-04 - mean_squared_error: 7.7402e-04 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
#
# Epoch 00082: val_mean_squared_error did not improve
# Epoch 83/100
# 1421/1421 [==============================] - 1s 451us/step - loss: 6.8871e-04 - mean_squared_error: 6.8871e-04 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
#
# Epoch 00083: val_mean_squared_error did not improve
# Epoch 84/100
# 1421/1421 [==============================] - 1s 407us/step - loss: 7.2342e-04 - mean_squared_error: 7.2342e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00084: val_mean_squared_error did not improve
# Epoch 85/100
# 1421/1421 [==============================] - 1s 469us/step - loss: 6.8176e-04 - mean_squared_error: 6.8176e-04 - val_loss: 9.1327e-04 - val_mean_squared_error: 9.1327e-04
#
# Epoch 00085: val_mean_squared_error did not improve
# Epoch 86/100
# 1421/1421 [==============================] - 1s 417us/step - loss: 7.0425e-04 - mean_squared_error: 7.0425e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00086: val_mean_squared_error did not improve
# Epoch 87/100
# 1421/1421 [==============================] - 1s 401us/step - loss: 6.4873e-04 - mean_squared_error: 6.4873e-04 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
#
# Epoch 00087: val_mean_squared_error did not improve
# Epoch 88/100
# 1421/1421 [==============================] - 1s 418us/step - loss: 7.0972e-04 - mean_squared_error: 7.0972e-04 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
#
# Epoch 00088: val_mean_squared_error did not improve
# Epoch 89/100
# 1421/1421 [==============================] - 1s 401us/step - loss: 6.9808e-04 - mean_squared_error: 6.9808e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
#
# Epoch 00089: val_mean_squared_error did not improve
# Epoch 90/100
# 1421/1421 [==============================] - 1s 398us/step - loss: 6.3346e-04 - mean_squared_error: 6.3346e-04 - val_loss: 0.0071 - val_mean_squared_error: 0.0071
#
# Epoch 00090: val_mean_squared_error did not improve
# Epoch 91/100
# 1421/1421 [==============================] - 1s 407us/step - loss: 6.7114e-04 - mean_squared_error: 6.7114e-04 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
#
# Epoch 00091: val_mean_squared_error did not improve
# Epoch 92/100
# 1421/1421 [==============================] - 1s 436us/step - loss: 6.9251e-04 - mean_squared_error: 6.9251e-04 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
#
# Epoch 00092: val_mean_squared_error did not improve
# Epoch 93/100
# 1421/1421 [==============================] - 1s 402us/step - loss: 7.3393e-04 - mean_squared_error: 7.3393e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# Epoch 00093: val_mean_squared_error did not improve
# Epoch 94/100
# 1421/1421 [==============================] - 1s 405us/step - loss: 6.5361e-04 - mean_squared_error: 6.5361e-04 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
#
# Epoch 00094: val_mean_squared_error did not improve
# Epoch 95/100
# 1421/1421 [==============================] - 1s 411us/step - loss: 6.7242e-04 - mean_squared_error: 6.7242e-04 - val_loss: 0.0043 - val_mean_squared_error: 0.0043
#
# Epoch 00095: val_mean_squared_error did not improve
# Epoch 96/100
# 1421/1421 [==============================] - 1s 401us/step - loss: 6.7300e-04 - mean_squared_error: 6.7300e-04 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
#
# Epoch 00096: val_mean_squared_error did not improve
# Epoch 97/100
# 1421/1421 [==============================] - 1s 433us/step - loss: 7.0309e-04 - mean_squared_error: 7.0309e-04 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
#
# Epoch 00097: val_mean_squared_error did not improve
# Epoch 98/100
# 1421/1421 [==============================] - 1s 436us/step - loss: 6.6300e-04 - mean_squared_error: 6.6300e-04 - val_loss: 8.5925e-04 - val_mean_squared_error: 8.5925e-04
#
# Epoch 00098: val_mean_squared_error did not improve
# Epoch 99/100
# 1421/1421 [==============================] - 1s 448us/step - loss: 6.8146e-04 - mean_squared_error: 6.8146e-04 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
#
# Epoch 00099: val_mean_squared_error did not improve
# Epoch 100/100
# 1421/1421 [==============================] - 1s 433us/step - loss: 6.4817e-04 - mean_squared_error: 6.4817e-04 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
#
# Epoch 00100: val_mean_squared_error did not improve

# %%
diff=[]
ratio=[]
predict = model.predict(X_test)
for d in range(len(y_test)):
    pred = predict[d][0]
    ratio.append((y_test[d]/pred)-1)
    diff.append(abs(y_test[d]- pred))

# %%
df = pd.read_csv("prices-split-adjusted.csv", index_col = 0)
df["mv close"] = df.close
df.drop(['volume', 'close'], 1, inplace=True)
df = df[df.symbol == SYM]
df.drop(['symbol'],1,inplace=True)

def denormalize(df, normalized_value): 
    df = df['mv close'].values.reshape(-1,1)
    normalized_value = normalized_value.reshape(-1,1)

    min_max_scaler = preprocessing.MinMaxScaler()
    _ = min_max_scaler.fit_transform(df)
    denorm = min_max_scaler.inverse_transform(normalized_value)
    return denorm

new_pred = denormalize(df, predict)
newy_test = denormalize(df, y_test)

# %%
def evaluation(model, X_test, y_test):
    score = model.evaluate(X_test, y_test, verbose=0)
    print('MSE: %.5f (RMSE: %.2f)' % (score[0], math.sqrt(score[0])))
    return score[0], math.sqrt(score[0])

evaluation(model, X_test, y_test)
# Out:
# MSE: 0.00058 (RMSE: 0.02)
# (0.0005802123092247971, 0.02408759658464906)

# %%
import random
random.seed(1997)

balance = 100000.0
cash_list= []
volume = 0
buyx = []
buyy =[]
selx = []
sely = []
for i in range(2,len(new_pred) - 1):
    prediction = new_pred[i]
    rand = random.randint(1, 100)
    if (prediction < new_pred[i-1] and balance != 0) or rand <= 5:
        if balance <= 10000:
            money = balance
            balance = 0
        else:
            money = 10000
            balance = balance - 10000
        volume += money / newy_test[i]
        buyx.append(i)
        buyy.append(newy_test[i])
        print("Buy " + str(newy_test[i]))
    elif(volume > 0 and prediction > new_pred[i-1] and prediction * 1.002 > new_pred[i-2]) or rand > 95:
        forSell = volume/4.0
        volume = volume*3.0/4.0
        balance += forSell * newy_test[i]
        selx.append(i)
        sely.append(newy_test[i])
        print("Sell " + str(newy_test[i]))
        print("Balance: " + str(balance))

if(volume != 0):
    balance += volume * newy_test[i]
    volume = 0
    selx.append(i)
    sely.append(newy_test[i])
    print("Sell : " + str(newy_test[i]))
    print("Balance : " + str(balance))
    
print("Balance : " + str(balance))
plt2.figure(figsize=(18,8))
plt2.scatter(buyx, buyy)
plt2.scatter(selx, sely)
# Out:
# Buy [708.140015]
# Buy [705.840027]
# Buy [691.02002]
# Buy [693.01001]
# Buy [698.210022]
# Buy [692.359985]
# Buy [695.700012]
# Buy [701.429993]
# Buy [711.119995]
# Sell [712.900024]
# Balance: [32928.43345899]
# Sell [723.179993]
# Balance: [50372.72837078]
# Sell [715.289978]
# Balance: [63313.20941747]
# Sell [713.309998]
# Balance: [72991.70498581]
# Sell [710.830017]
# Balance: [80225.33957876]
# Sell [716.48999]
# Balance: [85693.76380102]
# Sell [706.22998]
# Balance: [89736.35181658]
# Buy [706.630005]
# Buy [700.320007]
# Buy [709.73999]
# Buy [704.23999]
# Buy [720.090027]
# Sell [725.27002]
# Balance: [55652.3897732]
# Sell [724.119995]
# Balance: [67570.49028172]
# Sell [732.659973]
# Balance: [76614.48360162]
# Sell [735.719971]
# Balance: [83425.80817398]
# Sell [734.150024]
# Balance: [88523.40062972]
# Sell [730.400024]
# Balance: [92327.06629439]
# Sell [722.340027]
# Balance: [95148.33532709]
# Sell [716.549988]
# Balance: [97247.32633128]
# Buy [716.650024]
# Buy [728.280029]
# Buy [728.580017]
# Buy [719.409973]
# Buy [718.359985]
# Buy [718.27002]
# Buy [718.919983]
# Buy [710.359985]
# Buy [691.719971]
# Buy [693.710022]
# Sell [694.950012]
# Balance: [25162.79947775]
# Sell [697.77002]
# Balance: [44111.47937379]
# Sell [695.359985]
# Balance: [58273.90401652]
# Sell [705.630005]
# Balance: [69052.59992983]
# Sell [715.090027]
# Balance: [77245.00022856]
# Sell [720.640015]
# Balance: [83436.9878643]
# Buy [716.97998]
# Sell [720.950012]
# Balance: [80596.81918896]
# Sell [719.849976]
# Balance: [85958.49925148]
# Buy [733.780029]
# Buy [736.960022]
# Sell [741.190002]
# Balance: [75138.56527791]
# Sell [738.630005]
# Balance: [81999.83451728]
# Sell [742.73999]
# Balance: [87174.42024871]
# Buy [739.77002]
# Sell [738.419983]
# Balance: [83528.22444245]
# Sell [741.77002]
# Balance: [88315.19686909]
# Sell [745.909973]
# Balance: [91925.46390998]
# Sell [768.789978]
# Balance: [94716.22005289]
# Sell [772.880005]
# Balance: [96820.42245219]
# Sell [771.070007]
# Balance: [98394.87839774]
# Sell [773.179993]
# Balance: [99578.95165883]
# Buy [771.609985]
# Sell [782.219971]
# Balance: [93011.76582409]
# Sell [781.76001]
# Balance: [95584.86252545]
# Sell [784.26001]
# Balance: [97520.85645478]
# Sell [784.679993]
# Balance: [98973.62946713]
# Sell [784.849976]
# Balance: [100063.44525895]
# Sell [783.219971]
# Balance: [100879.10957599]
# Sell [782.440002]
# Balance: [101490.24860477]
# Sell [777.140015]
# Balance: [101945.49813774]
# Buy [779.909973]
# Buy [777.5]
# Buy [775.419983]
# Buy [772.150024]
# Buy [772.080017]
# Buy [769.640015]
# Buy [769.409973]
# Buy [769.539978]
# Buy [772.150024]
# Buy [769.090027]
# Buy [767.049988]
# Sell [780.349976]
# Balance: [26086.05608857]
# Sell [775.320007]
# Balance: [45524.48930241]
# Sell [759.659973]
# Balance: [59808.84884144]
# Sell [769.02002]
# Balance: [70654.12059014]
# Buy [759.690002]
# Buy [762.48999]
# Buy [771.76001]
# Buy [768.880005]
# Buy [765.700012]
# Buy [771.409973]
# Sell [776.219971]
# Balance: [34051.89155964]
# Sell [787.210022]
# Balance: [51848.67644775]
# Sell [786.900024]
# Balance: [65191.00892339]
# Sell [774.210022]
# Balance: [75036.38368935]
# Sell [783.01001]
# Balance: [82504.34468335]
# Buy [781.559998]
# Sell [775.01001]
# Balance: [80527.13875764]
# Sell [777.289978]
# Balance: [86561.9357432]
# Buy [772.559998]
# Buy [776.429993]
# Buy [776.469971]
# Buy [776.859985]
# Buy [775.080017]
# Buy [785.940002]
# Sell [783.070007]
# Balance: [46234.95723552]
# Sell [786.140015]
# Balance: [61047.56907687]
# Sell [778.190002]
# Balance: [72044.68112292]
# Sell [778.530029]
# Balance: [80296.11901546]
# Sell [779.960022]
# Balance: [86496.0645286]
# Sell [795.26001]
# Balance: [91237.23900393]
# Sell [801.5]
# Balance: [94821.02100057]
# Sell [796.969971]
# Balance: [97493.66601049]
# Sell [799.369995]
# Balance: [99504.18614232]
# Sell [813.109985]
# Balance: [101037.9946457]
# Sell [807.669983]
# Balance: [102180.65472001]
# Sell [799.070007]
# Balance: [103028.52459211]
# Sell [795.349976]
# Balance: [103661.46658391]
# Sell [795.369995]
# Balance: [104136.18502615]
# Buy [784.539978]
# Buy [783.609985]
# Buy [768.700012]
# Buy [762.130005]
# Buy [762.02002]
# Buy [782.52002]
# Buy [790.51001]
# Buy [785.309998]
# Sell [762.559998]
# Balance: [44098.96757453]
# Sell [754.02002]
# Balance: [58903.38073795]
# Buy [736.080017]
# Buy [758.48999]
# Buy [764.47998]
# Buy [771.22998]
# Buy [760.539978]
# Buy [769.200012]
# Sell [768.27002]
# Balance: [26206.07538987]
# Sell [760.98999]
# Balance: [45674.38782858]
# Sell [761.679993]
# Balance: [60288.86135343]
# Sell [768.23999]
# Balance: [71344.11726579]
# Sell [770.840027]
# Balance: [79663.62081635]
# Sell [758.039978]
# Balance: [85799.63743543]
# Sell [747.919983]
# Balance: [90340.21205413]
# Buy [750.5]
# Buy [762.52002]
# Buy [759.109985]
# Buy [771.190002]
# Buy [776.419983]
# Sell [789.289978]
# Balance: [56850.49915602]
# Sell [789.27002]
# Balance: [69232.90137289]
# Buy [796.099976]
# Sell [797.070007]
# Balance: [71114.52635639]
# Sell [797.849976]
# Balance: [80034.46512401]
# Sell [790.799988]
# Balance: [86665.30520916]
# Sell [794.200012]
# Balance: [91659.8171165]
# Buy [796.419983]
# Sell [794.559998]
# Balance: [87901.56035802]
# Buy [791.26001]
# Buy [789.909973]
# Buy [791.549988]
# Buy [785.049988]
# Sell : [785.049988]
# Balance : [106180.5437885]
# Balance : [106180.5437885]

# %%
plt2.figure(figsize=(18,8))
plt2.plot(new_pred,color='red', label='Prediction')
plt2.plot(newy_test,color='blue', label='Actual')
plt2.legend(loc='best')
plt2.scatter(buyx, buyy, color='green')
plt2.scatter(selx, sely, color='yellow')
plt2.show()
